# %% [markdown]
# -

# %% [markdown]
# #<center>[[---- Bad Comment Generator using RNN ----]]</center>
# ###<center>( 발표자료 : http://www.slideshare.net/shuraba1/bad-comment-generator-using-rnn )</center>
# <br><br>
# ###<p style="text-align:right">발표자 : 송치성(https://www.facebook.com/shuraba)</p>

# %% [markdown]
# # Goal :
# <hr style="border-color:#ff9900">
# ## 영화 악평들로 학습하는 Language Modeling을 통해 '악평생성기'를 만들어보자!

# %% [markdown]
# <br><br><br><br>
# # Step 1. Data Preprocessing
# <hr style="border-color:#ff9900">

# %% [markdown]
# - 데이터를 RNN으로 학습하기 좋은 형태로 전처리.

# %%
import os
import time
import random
import itertools
import pickle
import nltk
import numpy as np
import tensorflow as tf
from tensorflow.python.ops import rnn_cell
from tensorflow.python.ops import seq2seq

# %% [markdown]
# ## 0. Load Text Data & Attatch Sentence info(start or end)
# - 실습에 사용할 데이터 불러옴.
# - 실습데이터 : 평점 상위권 영화의 리뷰 중 악평들..

# %%
DATA_DIR = "./data"
INPUT_FILE = os.path.join(DATA_DIR, "bad_reviews.txt")

# %% [markdown]
# - 우리의 목적 : 이런 꼴이 되도록 만들자!
#     - 토크나이징 하기 전에 문장(리뷰)의 시작과 끝에 각각 특정 토큰을 붙임.
#     - 문장(리뷰)의 첫번째 단어와 마지막 단어는 어떤게 올지 학습이 가능.
# ![RNN example](img/RNN_example.png)

# %%
sentence_start_token = "SENTENCE_START"
sentence_end_token = "SENTENCE_END"

# %%
with open(INPUT_FILE, "r") as f:
    sentences = ['%s %s %s' % (sentence_start_token, line.strip(), sentence_end_token) for line in f.readlines()]

# %%
sentences[:8]
# Out:
# ['SENTENCE_START 극장에서 돈내고 보긴아깝다 SENTENCE_END',
#  'SENTENCE_START 진짜,, SENTENCE_END',
#  'SENTENCE_START 훌륭하지만 비약적인 스토리 SENTENCE_END',
#  'SENTENCE_START OOO야.. 아 진짜 후회했음 후회막급 ! ! 오빠테 욕먹었음... -_- SENTENCE_END',
#  'SENTENCE_START 잼씀 SENTENCE_END',
#  'SENTENCE_START 지 랄들 하세요 이민자들의 성공기 허울좋은 명분일뿐이고 마피아비판도 명분이고 마피아미화란 미화는 다 시키고 똥폼잡는작품 방구석에 처박혀서 이런거나보고 멋있다고 아우성는 저능아들을 위한작품 세상을 제대로알고 똑바로봐라 SENTENCE_END',
#  'SENTENCE_START 1~3편보고솔직히재미없다 SENTENCE_END',
#  'SENTENCE_START 진짜 심하게 지루하다 SENTENCE_END']

# %%
# 전체 리뷰 갯수
len(sentences)
# Out:
# 128173

# %%
# 실습을 위한 슬라이싱.
sentences = sentences[:1000]

# %%
len(sentences)
# Out:
# 1000

# %% [markdown]
# ## 1. Tokenize Sentences into words
# - __토큰화(Tokenize)__ : 자연어처리를 하기위하여 텍스트를 기본단위로 나누는 과정.
# - 어절 단위 vs 형태소 단위
#     - 본 실습에서는 __어절__단위로 토큰화. ( ex 동해물과/백두산이/마르고/닳도록 ...)
#     - 어절단위 토큰화 장단점:
#         - 장점: __빠르다__, 간단하다
#         - 단점: __교착어에 취약__ (ex. "치킨을" != "치킨이", "봤다" != "봤었다")
# - 이번 실습에서는 한 리뷰가 한 문장이라고 가정.

# %%
from konlpy.tag import Mecab
tagger = Mecab()
sample_review = "극장에서 돈내고 보긴 아깝다."

# %%
# 형태소 단위 Tokenizing
["%s/%s" % (word,pos) for word,pos in tagger.pos(sample_review)]
# Out:
# ['극장/NNG',
#  '에서/JKB',
#  '돈/NNG',
#  '내/VV',
#  '고/EC',
#  '보/VX',
#  '긴/ETN+JX',
#  '아깝/VA',
#  '다/EF',
#  './SF']

# %%
# 어절 단위 Tokenizing
sample_review.split()
# Out:
# ['극장에서', '돈내고', '보긴', '아깝다.']

# %%
sentences_tokenized = [sent.split() for sent in sentences]
sentences_tokenized[:8]
# Out:
# [['SENTENCE_START', '극장에서', '돈내고', '보긴아깝다', 'SENTENCE_END'],
#  ['SENTENCE_START', '진짜,,', 'SENTENCE_END'],
#  ['SENTENCE_START', '훌륭하지만', '비약적인', '스토리', 'SENTENCE_END'],
#  ['SENTENCE_START',
#   'OOO야..',
#   '아',
#   '진짜',
#   '후회했음',
#   '후회막급',
#   '!',
#   '!',
#   '오빠테',
#   '욕먹었음...',
#   '-_-',
#   'SENTENCE_END'],
#  ['SENTENCE_START', '잼씀', 'SENTENCE_END'],
#  ['SENTENCE_START',
#   '지',
#   '랄들',
#   '하세요',
#   '이민자들의',
#   '성공기',
#   '허울좋은',
#   '명분일뿐이고',
#   '마피아비판도',
#   '명분이고',
#   '마피아미화란',
#   '미화는',
#   '다',
#   '시키고',
#   '똥폼잡는작품',
#   '방구석에',
#   '처박혀서',
#   '이런거나보고',
#   '멋있다고',
#   '아우성는',
#   '저능아들을',
#   '위한작품',
#   '세상을',
#   '제대로알고',
#   '똑바로봐라',
#   'SENTENCE_END'],
#  ['SENTENCE_START', '1~3편보고솔직히재미없다', 'SENTENCE_END'],
#  ['SENTENCE_START', '진짜', '심하게', '지루하다', 'SENTENCE_END']]

# %%
# 전체 문장을 하나의 리스트로 변환.
text_tokenized = list(itertools.chain(*sentences_tokenized))
text_tokenized[:30]
# Out:
# ['SENTENCE_START',
#  '극장에서',
#  '돈내고',
#  '보긴아깝다',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '진짜,,',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '훌륭하지만',
#  '비약적인',
#  '스토리',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  'OOO야..',
#  '아',
#  '진짜',
#  '후회했음',
#  '후회막급',
#  '!',
#  '!',
#  '오빠테',
#  '욕먹었음...',
#  '-_-',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '잼씀',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '지']

# %% [markdown]
# ## 2. Word Indexing and Remove Infrequent Words
# - 각 단어에 고유의 인덱스(id)를 붙임.
# - 인덱스를 통한 one-hot vector 형태로 단어 표현. (cf. [Vector Representations of Words](https://www.tensorflow.org/versions/r0.8/tutorials/word2vec/index.html) )
# - 인덱스는 빈도순으로 줌.
# - 빈도수가 낮은 단어 제거 (기준 : 단어 사전 사이즈).

# %%
# 단어 개수 Threshold
vocab_size = 3000

# %%
# vocabulary 생성
word_freq = nltk.FreqDist(text_tokenized)
vocab = word_freq.most_common(vocab_size - 1)

# %%
# 전체 단어 갯수
len(vocab)
# Out:
# 2999

# %%
# 상위 빈도 10개 
vocab[:10]
# Out:
# [('SENTENCE_END', 1000),
#  ('SENTENCE_START', 1000),
#  ('너무', 62),
#  ('진짜', 55),
#  ('영화', 48),
#  ('정말', 40),
#  ('평점이', 31),
#  ('그냥', 29),
#  ('영화.', 23),
#  ('다', 20)]

# %%
# 하위 빈도 10개
vocab[-10:]
# Out:
# [('비상식적이고', 1),
#  ('.....usaOOO', 1),
#  ('그것이', 1),
#  ('뒷부분이.....', 1),
#  ('없는것', 1),
#  ('기내영화로', 1),
#  ('잼잇게', 1),
#  ('떨어지게', 1),
#  ('훨못하잖아..', 1),
#  ('머리아팠다.관객', 1)]

# %%
# 단어 분포 확인.

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.charts.attributes import CatAttr
from bokeh.charts import Dot
# from bokeh.models import ColumnDataSource, LabelSet
# from bokeh.models import HoverTool
output_notebook() # 주피터 노트북에서 볼때,
#output_file("chart.html") # 주피터노트북이 아닌 html로 출력할때,
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="faef798d-28c1-4a2e-beae-20a0c92ae0b5">Loading BokehJS ...</span>
#     </div>

# %%
data = {
    'token': [ ele[0] for ele in vocab][2:500],
    'freq': [ ele[1] for ele in vocab][2:500]
}
tools = "pan,wheel_zoom,box_zoom,reset,resize"

dots = Dot(data, values='freq', label=CatAttr(columns=['token'], sort=False), legend=False, title="Python Interpreter Sampling", width=600)

show(dots)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="77347dc2-b318-4414-8139-1f26b90c29f3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#77347dc2-b318-4414-8139-1f26b90c29f3").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("77347dc2-b318-4414-8139-1f26b90c29f3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '77347dc2-b318-4414-8139-1f26b90c29f3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"65ef335c-9fda-4fcb-a8c2-aa689488c317":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"f9ce90d1-331f-445d-874d-fda2766bf688","type":"Circle"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"b1048abb-9089-4120-a17c-7dbd5a5339c6","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y","line_color","height","color","line_alpha","label","fill_alpha","width"],"data":{"chart_index":[{"token":"\uc5f0\ucd9c"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[6.0],"label":[{"token":"\uc5f0\ucd9c"}],"line_alpha":[1.0],"line_color":["#f22c40"],"token":["\uc5f0\ucd9c"],"width":[0.8],"x":["\uc5f0\ucd9c"],"y":[3.0]}},"id":"af873f95-c48c-4cfe-9d39-be05da3bdc84","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","line_color","height","color","line_alpha","label","fill_alpha","width"],"data":{"chart_index":[{"token":"\uc544\uae4c\uc6cc"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":[{"token":"\uc544\uae4c\uc6cc"}],"line_alpha":[1.0],"line_color":["#f22c40"],"token":["\uc544\uae4c\uc6cc"],"width":[0.8],"x":["\uc544\uae4c\uc6cc"],"y":[1.5]}},"id":"969c3b8d-a780-4382-8d5d-8b18a56c81eb","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"d13bd495-9943-4410-8b05-ba4e0856e0d5","type":"Circle"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"79bb75d1-6e71-4f8b-8eed-c1b46c4da451","type":"Circle"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"41f848de-a1e6-4b58-94dc-2718eb52d5af","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y","line_color","height","color","line_alpha","label","fill_alpha","width"],"data":{"chart_index":[{"token":"\uc7ac\ubbf8\ub97c"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":[{"token":"\uc7ac\ubbf8\ub97c"}],"line_alpha":[1.0],"line_color":["#f22c40"],"token":["\uc7ac\ubbf8\ub97c"],"width":[0.8],"x":["\uc7ac\ubbf8\ub97c"],"y":[1.0]}},"id":"3e7b3431-cc1d-491d-8e05-0c72d101d239","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"fec64292-69e2-486a-9e1e-740ba41bb776","type":"ColumnDataSource"},"glyph":{"id":"ed61310c-9ac8-45f7-af15-3c70ba353419","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"20e18661-5f54-4fce-9f7e-bfbfe2d4d885","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","line_color","height","color","line_alpha","label","fill_alpha","width"],"data":{"chart_index":[{"token":"\ubc31\ub9c8\ud0c4"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":[{"token":"\ubc31\ub9c8\ud0c4"}],"line_alpha":[1.0],"line_color":["#f22c40"],"token":["\ubc31\ub9c8\ud0c4"],"width":[0.8],"x":["\ubc31\ub9c8\ud0c4"],"y":[1.0]}},"id":"0329f45d-e79b-43a6-a136-1a3750d9c740","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"7c43be25-ab8c-4814- ...

# %%
# 저빈도 단어는 "UNKNOWN_TOKEN"로 처리
unknown_token = "UNKNOWN_TOKEN"

# %%
def build_vocab(sentences, vocab_size, unknown_token):
    # vocab
    word_freq = nltk.FreqDist(text_tokenized)
    print("전체 단어 개수 : ", len(word_freq.items()))
    vocab = word_freq.most_common(vocab_size - 1)
    
    # Mapping from index to word
    id2word = [x[0] for x in vocab]
    id2word.append(unknown_token) # 사전에 없는단어 처리.
    # Mapping from word to index
    word2id = {w: i for i, w in enumerate(id2word)}

    return (word2id, id2word)

# %%
word2id, id2word = build_vocab(text_tokenized, vocab_size, unknown_token)
# Out:
# 전체 단어 개수 :  4724

# %%
word2id
# Out:
# {'끊김..똥같은영화들특징': 651,
#  '잤다': 182,
#  '대체': 126,
#  '내가싫어하는사람': 652,
#  '재미를': 307,
#  '느끼게': 293,
#  '초반에': 654,
#  '드물다.': 655,
#  '전쟁': 657,
#  '뭐야.': 658,
#  '토요일': 659,
#  '생각조차': 660,
#  '질르세요': 661,
#  '싶다는': 2346,
#  '킬링': 2837,
#  '지루함의': 308,
#  '사느냐에': 663,
#  '메릴스트립과': 664,
#  '만들었다고는': 665,
#  '시간낭비한기분': 667,
#  '유치.': 668,
#  '핵노잼': 669,
#  '유우.': 670,
#  '좋다': 671,
#  '일이다.': 672,
#  '조낸재미없다': 673,
#  '받는': 674,
#  '괜찮았다': 675,
#  '서부': 2686,
#  '1시간만에': 677,
#  '없네요': 309,
#  '미쳐서': 680,
#  '안봐야지': 681,
#  '돈에': 2687,
#  '잼없음잼없음잼없음': 682,
#  '말이': 683,
#  '영화가': 14,
#  '뭔가..': 684,
#  '보조자료': 685,
#  '4시정도에': 686,
#  '글쎄?': 687,
#  '안됨ㅡㅡ후반부에': 931,
#  '궂이': 689,
#  '작가가': 690,
#  '초속': 691,
#  '원작': 183,
#  '이하였습니다.': 692,
#  '9점이': 694,
#  '박수를': 1343,
#  '책에비해별로': 696,
#  '애초에': 697,
#  '퇴출대상': 1003,
#  '이런거나보고': 699,
#  '왜난': 700,
#  '맥퀸': 701,
#  '그게': 312,
#  '아닌': 127,
#  '생각된다....': 702,
#  '좀그래': 703,
#  '표현하고자한거같은데': 704,
#  '할머니들에게': 705,
#  '허지웅을': 706,
#  '정체를당당히': 707,
#  '쓰렉': 708,
#  '서양인의': 709,
#  ';;;;;시간아깝네요': 710,
#  '활발히': 711,
#  '미래는': 712,
#  '떨어뜨리자': 713,
#  '최하': 714,
#  'a급': 715,
#  '고통받으며': 717,
#  '끈끈한건지': 718,
#  '과장법~': 719,
#  '무더기': 720,
#  '급하게빠져들기': 721,
#  '보여주는': 184,
#  '친구들이': 722,
#  '다세포': 723,
#  '두': 355,
#  '용기가': 725,
#  '아닌가?': 2694,
#  '전자에서친구들에게': 728,
#  '녹아내려': 729,
#  '억지': 1713,
#  '느와르영화들에': 732,
#  '뭐여1970년대': 734,
#  '1박2일은': 735,
#  '연출은': 736,
#  '지루합니다..': 313,
#  '개가튼': 2780,
#  '실화라는걸': 738,
#  '로멘스': 1350,
#  '완전OOO기영화!!!!': 740,
#  '괜찮은': 314,
#  '7점대가': 742,
#  '남이하면': 743,
#  '머........': 1351,
#  '필이': 745,
#  '없고..': 746,
#  '이야기인데,': 748,
#  '존재하지만': 749,
#  '모든게': 315,
#  '나았을거': 750,
#  '잇엇으면': 751,
#  '평가된거': 752,
#  '안남은': 1319,
#  '들어왔다': 754,
#  '립싱크로': 755,
#  '돈내고봤는데': 756,
#  '평점에': 101,
#  '이런이런': 757,
#  '붕뜬느낌..': 758,
#  '여자들을': 759,
#  '아깝다.': 128,
#  '너무기대해서그런가': 762,
#  '팔아먹은건지?': 763,
#  '김민종': 316,
#  ',': 317,
#  '옮겨운': 764,
#  '짱OO들과': 765,
#  '삭제': 766,
#  '별이아깝다': 767,
#  '재미없다!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!': 768,
#  '달달한': 769,
#  '촬영과': 1108,
#  '그다지': 318,
#  '모르겠네요....': 770,
#  '나로썬': 771,
#  '역량이': 772,
#  '미야자키': 774,
#  '아니다.': 95,
#  '으이구': 776,
#  '연기...': 319,
#  '여운을': 778,
#  '떨어짐': 780,
#  '죽이고': 186,
#  '원래': 1317,
#  '성우': 783,
#  '미드': 2743,
#  '봐야지': 787,
#  '체': 788,
#  '노는': 789,
#  '해독방법도': 790,
#  '가볍게본다면': 791,
#  '지름길..-_-': 792,
#  '때문에': 187,
#  '즐쳐드세요...네?': 793,
#  '지루해서': 212,
#  '흠..그냥': 795,
#  '부합되지': 796,
#  '마지막': 72,
#  '장난슈': 797,
#  'ㅋㅋㅋㅋㅋ': 798,
#  '재미없어서': 320,
#  '좋았을텐데.': 799,
#  '만들었네요': 800,
#  '늘어지고': 801,
#  '인간의': 129,
#  '하거나,': 802,
#  '뵨사마': 1645,
#  '1점..': 804,
#  '별로없어여': 806,
#  '파파로티가': 807,
#  '이해하기': 808,
#  '못한': 321,
#  '걸작인건': 809,
#  '전개에': 810,
#  '이영화는': 811,
#  '억지로': 130,
#  '질질': 812,
#  '떨어진다.': 322,
#  '찾는': 813,
#  '설치는': 814,
#  '해피엔딩에': 816,
#  '헐낫다': 817,
#  '했다면,': 1363,
#  '봤는지': 819,
#  '처박혀서': 820,
#  '아주~': 821,
#  '수용소에서': 823,
#  '그녀를': 824,
#  '졸리씨?': 825,
#  '이태리(?)에서': 826,
#  '미화영화': 827,
#  '지점에서': 830,
#  '부족한듯;': 831,
#  '해대는것도': 832,
#  '보면': 47,
#  '부족': 833,
#  '에피소드의': 834,
#  '짜증나!!!!': 835,
#  '거는': 836,
#  '허구성을': 837,
#  '싸구려': 323,
#  '평점ㅡㅡ솔직히': 838,
#  '없었어요..좀': 840,
#  '정말0점주고싶다;;': 841,
#  '높은듯..': 842,
#  '과장된': 843,
#  '너무': 2,
#  '경향과': 844,
#  '억지눈물': 845,
#  '영화네....': 2718,
#  '드라마로': 847,
#  '영화봤는데': 848,
#  '이게뭐지..': 849,
#  '없는가.': 850,
#  '극단적이고': 415,
#  '멋있어서': 851,
#  '평점..인간의': 852,
#  '보나요?': 853,
#  '사람의': 326,
#  '삶이란': 854,
#  '평점내리기.': 855,
#  '남자가': 419,
#  '끌고영화의': 859,
#  '안타깝네요': 860,
#  '10억들었을까': 861,
#  '줄': 327,
#  '단어네': 863,
#  '분명': 864,
#  '좋을': 865,
#  '평점이높지??': 866,
#  '실망했다.': 867,
#  '구성을': 868,
#  '쩌내?ㅋ': 869,
#  '오와': 870,
#  '영화좀': 871,
#  '실망했음......': 872,
#  '그린': 873,
#  '보세요..욕': 874,
#  '꼭': 185,
#  '좋아하는데': 328,
#  '만들어도': 876,
#  '6점': 877,
#  '당했다...젠장': 878,
#  '전에': 879,
#  '급급한영화!!!!다시': 2074,
#  '회원끼리': 881,
#  '살인을': 883,
#  '떳네용..망한건가..': 884,
#  '소름': 885,
#  '영화평이': 886,
#  '오페라': 887,
#  '시간아까움': 888,
#  'ㅡㅡ.': 889,
#  '평점이': 6,
#  '생각이니': 891,
#  '올드하고': 892,
#  '본뒤에도': 893,
#  '속성을': 894,
#  '우리아이가': 895,
#  '하고': 188,
#  '감독이생각이': 897,
#  '아메리칸드림을': 2723,
#  '가지않는다': 899,
#  '만든다!!': 900,
#  '실망~ㅎ1편이': 901,
#  '원하는': 903,
#  '없음..절대': 904,
#  '편.': 905,
#  '최고': 330,
#  '영화드럽게': 906,
#  '뭔가': 131,
#  '약속이다.': 907,
#  '조절': 908,
#  '안나온다.': 910,
#  '서부극의': 911,
#  '저딴': 331,
#  '아침드라마구만': 913,
#  '앉고': 914,
#  'M창': 915,
#  '닮은배우가': 917,
#  '열바다': 918,
#  '후반으로': 332,
#  '나는': 235,
#  '하나...': 920,
#  '대표적': 921,
#  '말지': 922,
#  '나빴던': 923,
#  '미화하려고': 924,
#  '단순': 926,
#  '있는건..30살의': 927,
#  '진짜이건': 932,
#  '그런데': 944,
#  '보수': 933,
#  '기대하는가': 934,
#  '초딩수준의': 935,
#  '진짜..': 936,
#  '특히나': 937,
#  '색다르게': 938,
#  '내내': 33,
#  '립씽크의': 939,
#  '기대': 123,
#  '없고,': 189,
#  '3점을': 941,
#  '성매매': 942,
#  '내용에': 190,
#  '않네요~너무': 2730,
#  '쓰레기영화': 103,
#  '팬들만': 945,
#  '봤으나': 946,
#  '뱀을죽이라고하지도않았는데': 947,
#  '모지?': 948,
#  '개막장이었던': 951,
#  '공헌했음.': 2859,
#  '봤음': 334,
#  '토요일오후에': 2646,
#  '통찰력좀': 953,
#  '몰입감은': 954,
#  '묘': 955,
#  '안나네': 956,
#  '안쓰님?': 957,
#  '연대기의': 958,
#  '평점올려놓은거': 959,
#  '사랑스럽게': 960,
#  '만취후에': 961,
#  '만들것이다!': 963,
#  '졸음': 964,
#  '싫고쓰레기고엉터리고': 965,
#  '아주아주': 966,
#  '영화..': 73,
#  '여자의': 967,
#  '쳐다보는게': 968,
#  '토마스는': 969,
#  '산동네': 970,
#  '볼껀': 972,
#  '팬들': 973,
#  '내인생최악의쓰레기': 974,
#  '문제삼는게': 679,
#  '아닌듯': 976,
#  '만드니?': 977,
#  '감흥이떨어짐나체사진들은ㄹ혐오스러움.영화를': 978,
#  '꿈보다': 335,
#  '스크린쿼터': 979,
#  '5살에서': 980,
#  '시간낭비': 981,
#  '슬랩스틱': 982,
#  '접어드는가,,,': 984,
#  '되어있다.': 985,
#  '구체적': 986,
#  '괜찮을듯': 987,
#  '외쳐도': 988,
#  '장난?': 990,
#  '스토리는': 336,
#  '놓았다.': 2739,
#  '혼낫다.': 993,
#  '제일': 191,
#  '포스터가': 994,
#  '1점': 58,
#  '드럽게': 192,
#  '가따버러': 997,
#  '참..': 998,
#  '학생시절': 999,
#  '말까지떠오른다': 1000,
#  '쓰레기...': 1001,
#  '몸부림...': 337,
#  '못봐주겠다.': 1002,
#  '괜찮았는데..이번작은': 1004,
#  '굉장히': 132,
#  '상황을': 338,
#  '영화로구나.': 1006,
#  '쓰레기.': 193,
#  '못합니다.': 1007,
#  '망쳤다는': 1008,
#  '먼저': 1009,
#  '완전': 13,
#  '본개': 1011,
#  '로코가': 1012,
#  '뭔지도': 1013,
#  'going': 1014,
#  '보다시피': 1015,
#  '주성치의': 1016,
#  'ㅜㅜ': 339,
#  '맘에': 340,
#  '잼없어요시간낭비': 1018,
#  '모자라고': 1019,
#  '푸치니': 1020,
#  '원한다면': 595,
#  '생각해도': 1022,
#  '만화책보는': 1023,
#  '안봐서모르겠다': 1024,
#  '도데체': 1025,
#  '거죠?': 1026,
#  '한개도': 1027,
#  '똥이네똥..TT': 1028,
#  '후반부로': 1029,
#  '전작인': 1030,
#  '유지태연기는': 1031,
#  '정말...솔직히': 2746,
#  '와타나베와': 1033,
#  '대사도': 1034,
#  '쓰지맙시다!!': 1035,
#  '추천도많고': 1036,
#  '울었다네요ㅋㅋㅋㅋ': 1037,
#  '갑자기급': 1038,
#  '잼없었는데````````': 1039,
#  '대학생들이': 1040,
#  '한국애니도': 1041,
#  '낮게': 1042,
#  '일탈도': 1044,
#  '돼지들은': 1045,
#  '보았을때': 1046,
#  '처음부터': 194,
#  '싶은': 341,
#  '살은': 1047,
#  '별로에..기분더럽고': 1048,
#  '과장도': 1049,
#  '0점줘도': 1051,
#  '한다': 1052,
#  '억지눈물을': 1053,
#  '영화로': 104,
#  '말도': 195,
#  'bad': 303,
#  '사랑스럽지도': 1055,
#  '불편했습니다': 1056,
#  '문신있는': 1057,
#  '분은': 1058,
#  '와타나베를': 1059,
#  '의리': 1060,
#  '독일영화라고': 1062,
#  '-10000x10000은': 1063,
#  '바람을': 1064,
#  '이상도': 435,
#  '진지한': 342,
#  '그리': 343,
#  '위안부': 1066,
#  '객관적으로': 1067,
#  '영화라고..': 1068,
#  '페도충들이': 2717,
#  '영화보고': 1069,
#  '그녀,': 1070,
#  '알았는데': 1071,
#  '수준이': 344,
#  '못만든다': 1072,
#  '되지만': 1073,
#  '타임...': 805,
#  '한맺힌;;스토리': 1075,
#  '삶을': 1076,
#  '모르는건지평점올린놈들이장난하는건지둘중하나다': 1077,
#  '죽이는': 345,
#  '실화라서': 1078,
#  '전형적인': 346,
#  '된다': 347,
#  '원한은': 1080,
#  '작품을': 1081,
#  '있고,': 1082,
#  '주노라.': 1083,
#  '생략해버림;': 1084,
#  '중에서': 1085,
#  '쩌네..': 1086,
#  '억울하게': 1087,
#  '초딩용': 1088,
#  '잼씀': 1089,
#  '비행기다음으로': 1090,
#  '30분보고': 2758,
#  '자는게': 1091,
#  '주인공들이못생겨서': 1404,
#  '없다...': 1092,
#  '평론가의': 1094,
#  '선조격': 1095,
#  '만났네.': 1096,
#  '초대남/초대녀들': 1097,
#  '재미!': 2759,
#  '스토리에': 350,
#  '했지만,': 1100,
#  '성공기': 1101,
#  '별': 59,
#  '실망했고,': 1102,
#  '나옵니다': 1103,
#  '정상이냐': 1104,
#  '장면의': 1106,
#  '기대를': 1107,
#  '좋은듯...': 2279,
#  '뭐': 39,
#  '부추기는': 730,
#  '비현실적인': 1109,
#  '데이트하면서': 975,
#  '현실로': 1111,
#  '나왔습니다.완전비추': 1112,
#  '이거왜케': 1113,
#  '콜린': 1114,
#  '우뢰매~': 1115,
#  '속았다는': 1116,
#  '아쉽다.': 2766,
#  '쳇': 1118,
#  '을': 1119,
#  '쓰레기영화,': 1120,
#  '...': 78,
#  '차는': 1122,
#  '영화만': 1123,
#  '지루지루': 1124,
#  '바람난': 352,
#  '짜증': 1125,
#  '듯.스토리?중학생애를싸이코패스에서모범생으로개과천선': 1126,
#  '만드는군요..': 1127,
#  '재밌다.': 1128,
#  '억지다.': 1129,
#  '극소수에게만': 1130,
#  '멍하다.': 1131,
#  '잘된': 1132,
#  '서로': 1134,
#  '매력이': 353,
#  '안들고': 1135,
#  '절대보지마세요': 1136,
#  '전군의': 1137,
#  '같이': 134,
#  '보면서': 1138,
#  '오후': 1139,
#  '연출력이떨어져몰입하기가': 1140,
#  '의한,': 1141,
#  '완벽하다고?-_-': 1142,
#  '담임': 1143,
#  '드디어': 1144,
#  '들지만': 1145,
#  '쓰렉...ㅜㅜ': 1146,
#  '이명박': 1147,
#  '신파만': 1148,
#  '3천원': 1149,
#  '스피커끄고': 1150,
#  '침대는': 1151,
#  '모르겠음...': 1152,
#  '먼가': 1153,
#  '일본인들은': 1154,
#  '된거라고': 1155,
#  '오그라들어서': 1156,
#  '오페라가수의': 1157,
#  '돼지같은': 1158,
#  '마피아물과': 1160,
#  '중독성은': 1162,
#  '쓰세요??': 1164,
#  '충분히': 354,
#  '재미없었습니다.': 724,
#  '플롯조차': 1168,
#  '어휴..': 1169,
#  '보인다.': 1170,
#  '설정이너무억지스럽다': 1171,
#  '만드는게': 1172,
#  '상승이미지가': 1173,
#  '좋은영화를': 1174,
#  '됏을듯': 1175,
#  '어쩔건데': 1176,
#  '지루함': 105,
#  '않은데..;;;': 2778,
#  '힘들었습니다.': 1178,
#  '아후': 1179,
#  '싫어서': 1180,
#  '뚱녀의': 1181,
#  '봤는데': 74,
#  '반짜리': 1182,
#  '낫다': 1183,
#  '바람나서': 1184,
#  '잔인함': 1186,
#  '걸': 1187,
#  '친구랑': 1188,
#  '진부함.': 1189,
#  '다름없이': 1190,
#  '시간때우긴': 1192,
#  '기대햇는데;;': 1193,
#  '떨어지는': 962,
#  '힘든': 1195,
#  '길어서인가..약간운': 1197,
#  '언젠가': 1199,
#  '지루하다.': 356,
#  '최악이었다.': 1200,
#  '기대하고': 135,
#  '과학적으로': 1201,
#  '여주의': 357,
#  '한참된': 1203,
#  '싸이코': 1204,
#  '정말재밋어요': 943,
#  '괴롭힘': 1206,
#  '정서적으로': 1207,
#  ')미투': 1208,
#  '흐름': 1209,
#  '지겨워': 136,
#  '사랑을,': 1211,
#  '배경만': 1212,
#  '죄의': 1213,
#  '1점도': 75,
#  '반도': 1214,
#  '보다가': 56,
#  '나오던': 1217,
#  '쳐주고': 1218,
#  '정종석': 829,
#  '식상하는': 1220,
#  '비추천합니다.': 1223,
#  '잘생기지': 1224,
#  '5분': 1225,
#  '따라': 1226,
#  '기무라타쿠야': 1227,
#  '있어': 1017,
#  '드리겠습니다.': 1229,
#  '모두가': 1230,
#  '뜨뜨미지근했음;;': 1231,
#  '돈벌려고': 1232,
#  '최악이라는': 1233,
#  '따라야하며': 1234,
#  '찬양': 1235,
#  '<스카이폴>과': 1236,
#  '삼류...': 2719,
#  '사람을': 197,
#  '제작': 1238,
#  '가치도': 358,
#  '훌륭하지만': 2094,
#  '한국말': 1240,
#  '나이': 1241,
#  '되나요?--': 1242,
#  '사랑': 1243,
#  '남친!': 1244,
#  '믿을게': 2788,
#  '알았다': 1246,
#  '눈뜨고': 1247,
#  '점수가': 198,
#  '뻔한': 80,
#  '보니까': 1248,
#  '이명박때문이': 1249,
#  '기대이하..많이약하다,,,ㅋ': 1250,
#  '주접하는': 1251,
#  '했다': 359,
#  '살만하다': 1252,
#  '왔다.': 1253,
#  '믿지말자,': 1254,
#  '티비드라마': 1255,
#  '제로임.': 1256,
#  '토이스토리3의': 1257,
#  '있지만,': 1258,
#  '제': 1259,
#  '영화재미': 1260,
#  '남자랑': 1261,
#  '참아내느라': 1262,
#  '이거': 34,
#  '모르겠다': 1263,
#  '해리포터유명해서재밌는줄알았더만': 2012,
#  '찌질한': 2790,
#  '마법사...': 1266,
#  '상당히': 1267,
#  '보여주지': 1268,
#  '뭐하자는...': 1269,
#  '이런영화가': 199,
#  '비호감.': 1270,
#  '상황이': 1271,
#  '보여줬던': 1272,
#  'UCE': 1273,
#  '이스트우드가': 360,
#  '끝났다': 1274,
#  '놈놈놈이': 1275,
#  '핵노잼진짜이영화보다가지루해서잠왔음': 1276,
#  '중간': 304,
#  '다흘림': 1279,
#  '오~브리짓!': 1280,
#  '적당.': 1281,
#  '10점인지': 1282,
#  'ㅡㅡ;;': 1283,
#  '정신나간': 1285,
#  '공부': 1286,
#  '따분하고': 1437,
#  '사람들의': 200,
#  '쓰레기..': 361,
#  '욕설과': 1288,
#  '어색그자체다.카리스마없고': 1289,
#  '남자들': 1290,
#  '전문가평점': 1291,
#  '나가는': 1292,
#  '살지': 1293,
#  '성물': 1294,
#  '봤습니다.': 1295,
#  '투명망토를쓰지않았다.': 1296,
#  '가려진': 1299,
#  '나': 596,
#  '진부하고': 362,
#  '딱한가지': 1302,
#  '하세요': 1303,
#  '소용없다.': 1304,
#  '짜증난다.': 1305,
#  '알바쓰지마라': 1306,
#  '유치함': 634,
#  '쓸떼없는': 1308,
#  '자빠졋냐': 2483,
#  '불쾌하기': 1310,
#  '경민?': 1311,
#  '남편': 1312,
#  '살다가': 1313,
#  '조1또': 1315,
#  '일이': 363,
#  '전범국의': 1316,
#  '하나도없다.': 1318,
#  '영화,': 364,
#  '전개....': 2106,
#  '파파로티보다': 1321,
#  '말': 365,
#  '남는건': 1322,
#  '어설픈': 1323,
#  '왜보냐~': 1325,
#  '황당하기': 1326,
#  '있냐?': 1327,
#  '응답하라..': 1328,
#  '한번': 1329,
#  '6.5정도': 1330,
#  '일본껀': 1331,
#  '실화바탕이라곤': 1333,
#  '주제의식': 1334,
#  '와닿고': 1215,
#  '쌩뚱': 1336,
#  '잼있다고?': 1337,
#  '더스틴한테': 1339,
#  '레얼재미없음': 1340,
#  '여인들에게': 1341,
#  '무엇을': 366,
#  '가볍게': 695,
#  '동정도': 698,
#  '연기': 201,
#  '어두운': 2278,
#  '참나': 727,
#  '90년대': 1348,
#  '지루하죠.': 1349,
#  '첨엔': 902,
#  '아이들에게': 744,
#  '루즈함과': 1352,
#  '스타일.': 1353,
#  '영화임': 1354,
#  '한사람들은': 1355,
#  '알바들': 451,
#  '나쁜': 777,
#  '설.추석특집': 1357,
#  '해서': 202,
#  '재밌는데': 1358,
#  '웃기다': 1359,
#  '인간들이': 1360,
#  '이타심을': 1361,
#  '내가이걸': 1362,
#  '비현실같은': 818,
#  '스토리...': 1364,
#  '돈아깝고,': 1365,
#  '오래되서..': 2810,
#  '돌아오고,': 1367,
#  '생각으로': 1368,
#  '흉내낸': 1369,
#  '1편으로': 2731,
#  '마지막에도': 1370,
#  '초반엔': 1373,
#  '영화!!': 368,
#  '끊기고,': 1375,
#  '더빙도': 369,
#  '소설': 1377,
#  '유치해서': 370,
#  '일탈의': 1770,
#  '비현실적.': 1379,
#  '아까비': 1380,
#  '아흑..1,2편': 1381,
#  '어이없다.': 1382,
#  '아니다': 106,
#  '저': 203,
#  '못했다': 1383,
#  '잘살리지못해': 1384,
#  '기분나쁜': 1386,
#  '다분히..영화라고': 1387,
#  '당위성이': 1388,
#  '모든면에서': 1389,
#  '좋았다.': 1390,
#  '실화가아니었다면': 1391,
#  '뽑은': 1392,
#  'ㅡ,.ㅡ;;': 1393,
#  '불편했다.': 1394,
#  '오랜만이네.': 1395,
#  '주성치영화중': 2815,
#  '벌써': 1397,
#  '뭔영화인지': 1398,
#  '우리나라는': 1399,
#  '것..': 1400,
#  '안되었습니다.허영에': 1050,
#  '헌것이': 1402,
#  '같아서': 204,
#  '없다는': 1403,
#  '지루해': 133,
#  '뒷맛이': 1405,
#  '볼만하구나': 1406,
#  '제대로': 351,
#  '태도를': 1408,
#  '아래에': 1410,
#  '이런종류의': 1411,
#  '무섭긴': 1412,
#  '보답으로': 1413,
#  '지루해..': 1414,
#  '상황에서': 1416,
#  '떨어져라.': 1417,
#  '할짓인가?': 1418,
#  '별로네요..': 1419,
#  '부처네': 1420,
#  '졸려': 371,
#  '화가': 1421,
#  '미화는': 1422,
#  '안듬': 422,
#  '게다가': 1425,
#  '독창적이지도': 1426,
#  '영화가-_-': 1427,
#  '자기위안.': 1428,
#  '집에서': 1429,
#  '재미없게': 205,
#  '옛': 1430,
#  '네티즌': 583,
#  '저능아들을': 1432,
#  '장난하나': 1434,
#  '나와바..평': 1277,
#  '전문성우': 822,
#  '영화관에': 432,
#  '허세영화를': 1438,
#  '더빙이....내용에': 1202,
#  '77번만': 1440,
#  '2012년에': 1441,
#  '들었다.': 1442,
#  '너무재미잇어요': 1443,
#  '배우와': 1444,
#  '마피아미화': 1447,
#  '원빈': 1448,
#  '시리즈': 206,
#  '주인공교체하면영화가좀완벽해질라나?ㅋㅋ': 1449,
#  '더러워': 1450,
#  '이런건': 372,
#  '음악(비록': 1452,
#  '있다.': 137,
#  '사람들이': 1453,
#  '뭔데?': 1454,
#  '짱나는': 1462,
#  '돌림;-_-': 1456,
#  '자녀가': 1457,
#  '내용이라': 1415,
#  '쩝': 2344,
#  '전초전....이지만': 1460,
#  '보세요.': 207,
#  '그': 49,
#  '잘': 50,
#  '더빙은': 373,
#  '가정에': 1461,
#  '불필요해': 1455,
#  '개념없는': 1463,
#  '것밖에': 1464,
#  '소재를': 374,
#  '7점': 1465,
#  '알엇내': 1466,
#  '쿼터가만들어낸': 1468,
#  '있음!!!': 1469,
#  '딴사람': 1470,
#  '작품': 208,
#  '걍': 77,
#  '준': 209,
#  '볼려고': 1196,
#  '매끄럽지않다': 2281,
#  '유우': 379,
#  '보여준': 1475,
#  '영화냐...초딩용': 1476,
#  '밤에': 1477,
#  '끝까지': 375,
#  '다크나이트': 1478,
#  '재밋을까?': 1479,
#  'SENTENCE_END': 0,
#  '극단적이다...': 1480,
#  '최악..': 376,
#  '끌면서..': 1481,
#  '떨어진다.국제시장에': 1483,
#  '전쟁에서': 1486,
#  '만들었냐?': 1487,
#  '특이할것': 1488,
#  '화이링~!!': 1489,
#  '부르는거': 1490,
#  '좋네머': 1491,
#  '메마른': 1492,
#  '여친이랑': 1493,
#  '느낌은': 1495,
#  '기대이한데': 1496,
#  '중간까지': 1497,
#  '나오면서': 1498,
#  '흠': 1499,
#  '때문일까': 1099,
#  '갑갑한': 1502,
#  '느낌..': 1503,
#  '2부를': 1506,
#  '나온나~!': 1507,
#  '이보다': 1509,
#  '"부족한': 1510,
#  '개막장': 1511,
#  '이영화': 52,
#  '잠만': 377,
#  '철이랑': 1513,
#  '시간만': 378,
#  '음악만유명할뿐': 1514,
#  '계획적이었는데.': 1515,
#  '합리화할수없다.': 1516,
#  '이거보고': 1517,
#  '결점들?"': 1518,
#  '않은게': 1519,
#  '울': 472,
#  '든': 1520,
#  '요즘': 1521,
#  '재밌는주제일': 1522,
#  '딱': 51,
#  '극한': 2083,
#  '짱공유가서': 1524,
#  '오빠테': 1185,
#  '기분더러워지는': 1526,
#  '이영화가': 210,
#  '없다': 35,
#  '누굴': 1527,
#  '지루했네요': 1528,
#  '몇개있고...남자친구는': 1529,
#  '재미없었어요..': 1530,
#  '다운받지': 1531,
#  '억지스럽고': 380,
#  '영....': 1532,
#  '된게': 1534,
#  '배우의': 1535,
#  '많다는게': 1537,
#  '한국인들의': 1538,
#  '일본만화는': 2299,
#  '알바많네..': 1540,
#  '고전스토리에': 1541,
#  '전부': 381,
#  '활동한다는': 1542,
#  '돈주고': 211,
#  '같이보러가자고': 1543,
#  '트루먼숀가..?!!!': 1544,
#  '생겨서': 382,
#  '열받아서': 1546,
#  '샀건만': 2148,
#  '알바조심': 1547,
#  '있을거라는...연민을': 1627,
#  '뿐이다.이게': 1549,
#  '아오이': 224,
#  '이스트우드를': 1551,
#  '부족함.': 2787,
#  '주기도': 1553,
#  '실험을': 1554,
#  '빠졌다!ㅋ팬이됨.': 1555,
#  '재미없어용': 1556,
#  '마냥': 1557,
#  '음악말고는': 1558,
#  '걸작인가요?+ㅇ+': 1559,
#  '수준낮은': 2040,
#  '허접한': 1561,
#  '해리': 1562,
#  '떨어질때도': 1563,
#  '정말???': 2841,
#  '랄들': 1566,
#  '유치': 1567,
#  '이후로': 384,
#  '따른': 2152,
#  '단체로': 1569,
#  '떠벌려논영화내용-_-': 1570,
#  '정해놓지': 1571,
#  '야장난하냐': 1572,
#  '최악이다ㅡㅡ..': 1573,
#  '쓰래기': 1574,
#  '사기인': 1575,
#  '무자게': 1576,
#  '청소년': 794,
#  '바꿀수': 656,
#  '설득력': 2143,
#  '작품성이': 1579,
#  '포함': 1580,
#  '별론데?': 1581,
#  '끈': 1582,
#  '생각하는': 1583,
#  '감동은..-_-너무': 1584,
#  '개봉해??': 1585,
#  '유치뽕짝': 1587,
#  '무식하고': 1589,
#  '그렇고..': 1590,
#  '지루했던': 385,
#  '살아남는': 1591,
#  '안뜨냐': 1920,
#  '기억': 1593,
#  '쌔고쌨는데ㅉㅉㅉ': 1594,
#  '비슷한듯': 1595,
#  '마이너스는': 1596,
#  '보다': 79,
#  '분노만이': 2228,
#  '못했다.': 1598,
#  '있고...특히': 1601,
#  '내용도': 138,
#  '진부한': 387,
#  '하기를....': 1602,
#  '짱난다': 1791,
#  '영화1위.그래서': 1604,
#  '관련된': 571,
#  '진행': 2716,
#  '6점이': 1607,
#  '심오한걸': 1608,
#  '있냐.평점': 1609,
#  '8점정도가': 1610,
#  '높네': 1611,
#  'OOO기': 1612,
#  '이런거지.': 1614,
#  '이제': 268,
#  '수가': 1616,
#  '뭘까?': 388,
#  '또는': 1617,
#  '했네요...': 1618,
#  'OOO..': 1619,
#  '원작이': 1620,
#  ...}

# %%
# 단어 -> index
word2id["영화"]
# Out:
# 4

# %%
id2word[:10]
# Out:
# ['SENTENCE_END',
#  'SENTENCE_START',
#  '너무',
#  '진짜',
#  '영화',
#  '정말',
#  '평점이',
#  '그냥',
#  '영화.',
#  '다']

# %%
id2word[-10:]
# Out:
# ['.....usaOOO',
#  '그것이',
#  '뒷부분이.....',
#  '없는것',
#  '기내영화로',
#  '잼잇게',
#  '떨어지게',
#  '훨못하잖아..',
#  '머리아팠다.관객',
#  'UNKNOWN_TOKEN']

# %%
# 전체 단어 개수
len(id2word)
# Out:
# 3000

# %%
# index -> 단어
id2word[2]
# Out:
# '너무'

# %%
# 원래 이랬던 리뷰 데이터가..
text_tokenized[:30]
# Out:
# ['SENTENCE_START',
#  '극장에서',
#  '돈내고',
#  '보긴아깝다',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '진짜,,',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '훌륭하지만',
#  '비약적인',
#  '스토리',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  'OOO야..',
#  '아',
#  '진짜',
#  '후회했음',
#  '후회막급',
#  '!',
#  '!',
#  '오빠테',
#  '욕먹었음...',
#  '-_-',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '잼씀',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '지']

# %%
# 저빈도 단어 필터링 ( 토크나이징된 데이터 중 단어 사전에 등록된 것이 있으면 그대로 쓰고, 없으면 UNKNOWN_TOKEN로 대체.)
text_tokenized = [w if w in word2id else unknown_token for w in text_tokenized]
text_tokenized[:30]
# Out:
# ['SENTENCE_START',
#  '극장에서',
#  '돈내고',
#  '보긴아깝다',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '진짜,,',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '훌륭하지만',
#  'UNKNOWN_TOKEN',
#  '스토리',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  'OOO야..',
#  '아',
#  '진짜',
#  'UNKNOWN_TOKEN',
#  '후회막급',
#  '!',
#  '!',
#  '오빠테',
#  'UNKNOWN_TOKEN',
#  '-_-',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '잼씀',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '지']

# %%
# 위의 데이터에서 각 단어를 학습을 위해 id로 치환.
tensor = np.array(list(map(word2id.get, text_tokenized)))

# %%
tensor[:100]
# Out:
# array([   1,   94,  559, 2437,    0,    1, 1159,    0,    1, 2094, 2999,
#          40,    0,    1, 2009,   53,    3, 2999, 1857,  529,  529, 1185,
#        2999,  109,    0,    1, 1089,    0,    1, 2631, 1566, 1303, 2999,
#        1101, 2999, 1735, 2999, 2806, 2999, 1422,    9, 2999, 2999, 2999,
#         820,  699, 2428, 2052, 1432, 2047,  561, 2999, 2999,    0,    1,
#        1955,    0,    1,    3, 2999,  237,    0,    1,  285,    0,    1,
#        2999,  425, 2999,   26, 1042, 1218,  341,  587,    0,    1, 2990,
#           0,    1,   66, 2850,  136,    0,    1,  687,    0,    1, 1249,
#         641,   11,   23, 2999,  211,  556,  252,  181,    4,    0,    1,
#          19])

# %% [markdown]
# ## 3. Build Batches for Training

# %%
batch_size = 20 # 배치사이즈
seq_length = 10 # rnn 모델에서 t의 사이즈

# %%
def create_batches(tensor, batch_size, seq_length):
    num_batches = int(tensor.size / (batch_size * seq_length))
    if num_batches == 0:
        assert False, "Not enough data. Make seq_length and batch_size small."

    tensor = tensor[:num_batches * batch_size * seq_length]
    xdata = tensor
    ydata = np.copy(tensor)

    ydata[:-1] = xdata[1:]
    ydata[-1] = xdata[0]
    x_batches = np.split(xdata.reshape(batch_size, -1), num_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), num_batches, 1)

    return x_batches, y_batches

# %%
x_batches, y_batches = create_batches(tensor, batch_size, seq_length)
num_batches = len(x_batches)

# %%
num_batches
# Out:
# 43

# %% [markdown]
# ### 전처리 결과

# %%
# 원 문장
text_tokenized[:5]
# Out:
# ['SENTENCE_START', '극장에서', '돈내고', '보긴아깝다', 'SENTENCE_END']

# %%
# 원 문장 각 단어를 인덱스로 표현
[word2id[w] for w in text_tokenized[:5]]
# Out:
# [1, 94, 559, 2437, 0]

# %%
# 학습에 사용되는 X_train 데이터
x_batches[1]
# Out:
# array([[2999,   40,    0,    1, 2009,   53,    3, 2999, 1857,  529],
#        [   0,    1, 2999,  191, 2999, 2999, 1885,    0,    1,  734],
#        [   1, 1925, 1187,  145, 1585,    0,    1,  213, 2999, 2999],
#        [ 158, 2425,    0,    1,  559, 2518, 2999,   43,    0,    1],
#        [ 150, 1682,    0,    1, 2999,    5, 2999,  325, 2999, 2999],
#        [   0,    1, 2785,  114, 1366,    0,    1,    2, 2364,   24],
#        [ 551,  622,   77, 1285,  967, 2999,    0,    1,  226,    0],
#        [   1, 1939,  706, 1798,    4, 2999, 2999, 2999,    2, 1483],
#        [2999, 2999, 1458,    0,    1, 2999, 1686, 2764, 2642,   60],
#        [   0,    1, 1491,    0,    1,   41, 2999,  505, 2603,   70],
#        [1859,    0,    1,  412, 2999,  514,    6, 2999,    0,    1],
#        [ 523,    9,  186,   14, 2616,  799,    0,    1, 2261, 2999],
#        [2245,    4,  259,    0,    1,  129, 2999, 1412, 2999,    0],
#        [2800,    0,    1,   52, 2999,  642, 2999, 1314, 2719,    0],
#        [2862,  589, 2171, 2999,    0,    1,  124, 2250,    0,    1],
#        [   0,    1,   32, 1260,    2, 2170, 2999,  642,    0,    1],
#        [   0,    1,  465,  741, 2680,  330, 2999,    4,    0,    1],
#        [2999,    0,    1, 2999,   29, 2999,   38, 2999,    0,    1],
#        [   1, 2999,  478, 2601, 2856,   42, 1938, 2999, 2715,    0],
#        [   1, 1540,   20, 2999, 2296,  297,   55,  297,    0,    1]])

# %%
# 학습에 사용되는 y_train 데이터
y_batches[1]
# Out:
# array([[  40,    0,    1, 2009,   53,    3, 2999, 1857,  529,  529],
#        [   1, 2999,  191, 2999, 2999, 1885,    0,    1,  734,   27],
#        [1925, 1187,  145, 1585,    0,    1,  213, 2999, 2999,    0],
#        [2425,    0,    1,  559, 2518, 2999,   43,    0,    1, 1259],
#        [1682,    0,    1, 2999,    5, 2999,  325, 2999, 2999, 2999],
#        [   1, 2785,  114, 1366,    0,    1,    2, 2364,   24,  230],
#        [ 622,   77, 1285,  967, 2999,    0,    1,  226,    0,    1],
#        [1939,  706, 1798,    4, 2999, 2999, 2999,    2, 1483, 2999],
#        [2999, 1458,    0,    1, 2999, 1686, 2764, 2642,   60, 2999],
#        [   1, 1491,    0,    1,   41, 2999,  505, 2603,   70, 1460],
#        [   0,    1,  412, 2999,  514,    6, 2999,    0,    1,  503],
#        [   9,  186,   14, 2616,  799,    0,    1, 2261, 2999,    0],
#        [   4,  259,    0,    1,  129, 2999, 1412, 2999,    0,    1],
#        [   0,    1,   52, 2999,  642, 2999, 1314, 2719,    0,    1],
#        [ 589, 2171, 2999,    0,    1,  124, 2250,    0,    1, 2999],
#        [   1,   32, 1260,    2, 2170, 2999,  642,    0,    1,    3],
#        [   1,  465,  741, 2680,  330, 2999,    4,    0,    1, 2999],
#        [   0,    1, 2999,   29, 2999,   38, 2999,    0,    1, 2999],
#        [2999,  478, 2601, 2856,   42, 1938, 2999, 2715,    0,    1],
#        [1540,   20, 2999, 2296,  297,   55,  297,    0,    1, 2482]])

# %% [markdown]
# <br><br><br><br>
# # Step 2. RNN Modeling
# <hr style="border-color:#ff9900">
# ![](img/RNN_model.png)

# %% [markdown]
# ## 1. Initialization
# - 파라미터 U,V,W 를 초기화.

# %%
args = {}
args['data_dir'] = './data'
args['log_dir'] = './logs'
args['save_dir'] = './save'
args['rnn_size'] = 256
args['num_layers'] = 5
args['model'] = 'lstm'
args['batch_size'] = batch_size
args['seq_length'] = seq_length
args['num_epochs'] = 10
args['save_every'] = 1000
args['grad_clip'] = 5
args['learning_rate'] = 0.002 
args['decay_rate'] = 0.97 
args['vocab_size'] = vocab_size

# %% [markdown]
# <img src="https://qph.ec.quoracdn.net/main-qimg-1ec77cdbb354c3b9d439fbe436dc5d4f" />

# %%
with open(os.path.join(args['save_dir'], 'config.pkl'), 'wb') as f:
    pickle.dump(args, f)
with open(os.path.join(args['save_dir'], 'words_vocab.pkl'), 'wb') as f:
    pickle.dump((id2word, word2id), f)

# %%
class Model():
    def __init__(self, args, infer=False):
        self.args = args
        if infer:
            args['batch_size'] = 1
            args['seq_length'] = 1

        if args['model'] == 'rnn':
            cell_fn = rnn_cell.BasicRNNCell
        elif args['model'] == 'gru':
            cell_fn = rnn_cell.GRUCell
        elif args['model'] == 'lstm':
            cell_fn = rnn_cell.LSTMCell
        else:
            raise Exception("model type not supported: {}".format(args['model']))

        cell = cell_fn(args['rnn_size'])

        self.cell = cell = rnn_cell.MultiRNNCell([cell] * args['num_layers'])
        self.input_data = tf.placeholder(tf.int32, [args['batch_size'], args['seq_length']])
        self.targets = tf.placeholder(tf.int32, [args['batch_size'], args['seq_length']])
        self.initial_state = cell.zero_state(args['batch_size'], tf.float32)
        self.epoch_pointer = tf.Variable(0, name="epoch_pointer", trainable=False)
        self.batch_time = tf.Variable(0.0, name="batch_time", trainable=False)

        softmax_w = tf.get_variable("softmax_w", [args['rnn_size'], args['vocab_size']])
        softmax_b = tf.get_variable("softmax_b", [args['vocab_size']])
        with tf.device("/cpu:0"):
            embedding = tf.get_variable("embedding", [args['vocab_size'], args['rnn_size']])
            inputs = tf.split(1, args['seq_length'], tf.nn.embedding_lookup(embedding, self.input_data))
            inputs = [tf.squeeze(input_, [1]) for input_ in inputs]

        def loop(prev, _):
            prev = tf.matmul(prev, softmax_w) + softmax_b
            prev_symbol = tf.stop_gradient(tf.argmax(prev, 1))
            return tf.nn.embedding_lookup(embedding, prev_symbol)

        outputs, last_state = seq2seq.rnn_decoder(inputs, self.initial_state, cell, loop_function=loop if infer else None, scope='rnnlm')
        # outputs, last_state = tf.nn.bidirectional_dynamic_rnn()
        output = tf.reshape(tf.concat(1, outputs), [-1, args['rnn_size']])
        self.logits = tf.matmul(output, softmax_w) + softmax_b
        self.probs = tf.nn.softmax(self.logits)
        loss = seq2seq.sequence_loss_by_example([self.logits],
                                                [tf.reshape(self.targets, [-1])],
                                                [tf.ones([args['batch_size'] * args['seq_length']])],
                                                args['vocab_size'])
        self.cost = tf.reduce_sum(loss) / args['batch_size'] / args['seq_length']
        self.final_state = last_state
        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars), args['grad_clip'])
        optimizer = tf.train.AdamOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def sample(self, sess, id2word, word2id, prime='SENTENCE_START'):
        state = sess.run(self.cell.zero_state(1, tf.float32))

        if not len(prime) or prime == " ":
            prime = random.choice(list(word2id.keys()))

        def weighted_pick(weights):
            t = np.cumsum(weights)
            s = np.sum(weights)
            return (int(np.searchsorted(t, np.random.rand(1) * s)))
        sent = [prime]
        word = prime.split()[-1]
        n = 0
        while sent[-1] != 'SENTENCE_END':
            x = np.zeros((1, 1))
            x[0, 0] = word2id[word]
            feed = {self.input_data: x, self.initial_state: state}
            probs, state = sess.run([self.probs, self.final_state], feed)
            p = probs[0]
            sample = weighted_pick(p)
            pred = id2word[sample]
            if pred == "UNKNOWN_TOKEN":
                continue
            sent.append(pred)
            word = pred
        return sent[1:-1]

# %%
model = Model(args)

# %%
with tf.Session() as sess:
    tf.global_variables_initializer().run() # tf 변수들 초기화
    saver = tf.train.Saver(tf.global_variables())

    for e in range(model.epoch_pointer.eval(), args['num_epochs']):
        print('\n\n--------- epoch : %i -----------\n\n' % e)
        sess.run(tf.assign(model.lr, args['learning_rate'] * (args['decay_rate'] ** e)))  # model.lr에 값 할당.
        state = sess.run(model.initial_state)
        speed = 0

        for b, (x_batch, y_batch) in enumerate(zip(x_batches, y_batches)):
            start = time.time()

            feed = {model.input_data: x_batch,
                    model.targets: y_batch,
                    model.initial_state: state,
                    model.batch_time: speed
                    }
            train_loss, state, _ = sess.run([model.cost, model.final_state, model.train_op], feed)
            speed = time.time() - start
            if (e * num_batches + b) % args['batch_size'] == 0:
                print("{}/{} (epoch {}), train_loss = {:.3f}, time/batch = {:.3f}".format(e * num_batches + b, args['num_epochs'] * num_batches, e, train_loss, speed))
            if (e * num_batches + b) % args['save_every'] == 0 or (e == args['num_epochs'] - 1 and b == num_batches - 1):  # save for the last result
                checkpoint_path = os.path.join(args['save_dir'], 'model.ckpt')
                saver.save(sess, checkpoint_path, global_step=e * num_batches + b)
                print("model saved to {}".format(checkpoint_path))
# Out:
# --------- epoch : 0 -----------
#
#
# 0/430 (epoch 0), train_loss = 8.498, time/batch = 0.313
# model saved to ./save/model.ckpt
# 20/430 (epoch 0), train_loss = 6.129, time/batch = 0.116
# 40/430 (epoch 0), train_loss = 6.346, time/batch = 0.109
#
#
# --------- epoch : 1 -----------
#
#
# 60/430 (epoch 1), train_loss = 5.655, time/batch = 0.103
# 80/430 (epoch 1), train_loss = 6.462, time/batch = 0.106
#
#
# --------- epoch : 2 -----------
#
#
# 100/430 (epoch 2), train_loss = 5.329, time/batch = 0.116
# 120/430 (epoch 2), train_loss = 5.828, time/batch = 0.114
#
#
# --------- epoch : 3 -----------
#
#
# 140/430 (epoch 3), train_loss = 5.677, time/batch = 0.109
# 160/430 (epoch 3), train_loss = 5.567, time/batch = 0.112
#
#
# --------- epoch : 4 -----------
#
#
# 180/430 (epoch 4), train_loss = 5.703, time/batch = 0.121
# 200/430 (epoch 4), train_loss = 5.848, time/batch = 0.116
#
#
# --------- epoch : 5 -----------
#
#
# 220/430 (epoch 5), train_loss = 5.360, time/batch = 0.120
# 240/430 (epoch 5), train_loss = 5.633, time/batch = 0.116
#
#
# --------- epoch : 6 -----------
#
#
# 260/430 (epoch 6), train_loss = 5.454, time/batch = 0.136
# 280/430 (epoch 6), train_loss = 5.587, time/batch = 0.148
# 300/430 (epoch 6), train_loss = 5.859, time/batch = 0.118
#
#
# --------- epoch : 7 -----------
#
#
# 320/430 (epoch 7), train_loss = 5.250, time/batch = 0.153
# 340/430 (epoch 7), train_loss = 5.364, time/batch = 0.124
#
#
# --------- epoch : 8 -----------
#
#
# 360/430 (epoch 8), train_loss = 5.216, time/batch = 0.116
# 380/430 (epoch 8), train_loss = 5.193, time/batch = 0.120
#
#
# --------- epoch : 9 -----------
#
#
# 400/430 (epoch 9), train_loss = 5.599, time/batch = 0.117
# 420/430 (epoch 9), train_loss = 5.271, time/batch = 0.119
# model saved to ./save/model.ckpt

# %% [markdown]
# <br><br><br><br>
# # Step 3. Generating Text
# <hr style="border-color:#ff9900">

# %% [markdown]
# ### 저장된 모델 불러오기

# %%
args={}
args['save_dir'] = './save'
args['prime'] = 'SENTENCE_START'

# %%
with open(os.path.join(args['save_dir'], 'config.pkl'), 'rb') as f:
    saved_args = pickle.load(f)
with open(os.path.join(args['save_dir'], 'words_vocab.pkl'), 'rb') as f:
    id2word, word2id = pickle.load(f)

# %%
tf.reset_default_graph() # 그래프 리셋
model_gen = Model(saved_args, infer=True)

# %% [markdown]
# ### 악평 생성하기

# %%
# 생성할 문장 수
num_sentences = 10
# 문장의 최소 길이
senten_min_length = 4

# %%
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    saver = tf.train.Saver(tf.global_variables())
    ckpt = tf.train.get_checkpoint_state(args['save_dir'])
    print(ckpt.model_checkpoint_path)
    if ckpt and ckpt.model_checkpoint_path:
        saver.restore(sess, ckpt.model_checkpoint_path)
        for _ in range(num_sentences):
            bot_sent = []
            while len(bot_sent) < senten_min_length:
                bot_sent = model_gen.sample(sess, id2word, word2id, args['prime'])
            print(' '.join(bot_sent))
            print()
# Out:
# ./save/model.ckpt-429
# 머하는거지? 중간까지 손발 어설프다...지루하다.. 찬사를 너무 최저. 없음. 의리 가정에 죽겠다. 오와 없는 실화라는 할수 충분히 최악의 아쉽다 감동 재미없는
#
# 시리즈중 관계자들이 3류보다 서부극 의리!있는 작가가 SENTENCE_START 피해망상 SENTENCE_START SENTENCE_START 맞는건지는 괜찮았는데..이번작은 쓰기에 SENTENCE_START 허지웅을 SENTENCE_START 제대로된 영화...연출력도
#
# 발전한것 팬들 보고 SENTENCE_START 오바심함
#
# 매번 그들은 후회막급 영!! 낭비했다.
#
# 잃어버린 이해되질 없음..절대 이야기이네요...근디 감동포인트를 했다. 흠..그냥 실망 못한
#
# 역량이 일본만화는 떡 최악이라는 메릴스트립과 런닝타임만 쓰레기. SENTENCE_START 한 쌔고쌨는데ㅉㅉㅉ 한것 진짜 재밌었다... 아닌데... 또는 SENTENCE_START 진짜,, 재능 꺄악꺄악...-_- 추억의 인간의 애니를 수동적으로 너무 아까운영화 딱히 SENTENCE_START 오만은 SENTENCE_START SENTENCE_START 영화는 너무
#
# ffff 몰락의 딱 박수칠때 지루하고 요새 SENTENCE_START 평론가들에게
#
# 학대해도 머하는거지? 미쳐서 시간아깝다. 울
#
# 실제로 2점부터 싫고쓰레기고엉터리고 안돼 ㅡㅡ 진짜 SENTENCE_START SENTENCE_START 이영화에 영화가
#
# 일탈도 아니라 7점 싫다 를 전작을 안됨 SENTENCE_START 보기도 SENTENCE_START SENTENCE_START 많았던것 못하네요.. 일본 듣기 쓰레기다. ㅋㅋ 잠들었다 뻔하고 체 SENTENCE_START 영화...연출력도 만들어도 8점대래? SENTENCE_START 영화관에 열심히 권력을 아.. 다 초,중,고딩용 SENTENCE_START 좋은 SENTENCE_START 이런 죽여야만
#
# 중간에 안됨 토나온다고 해달라.누가 별내용도 오지게 , 정신나간 하기는... 학생인 공헌했음.
#
# 보니까 감정선이 아쉽다 나와서 이런거지. 사느냐에 조연들... 애니메이션으로 15세
#
# 한사람들은 약속이다. 애니메이션!! 영화가되길 봤네; 에피소드의 애니메이션과 젊은남자를 SENTENCE_START 더빙도 기대에 분노가
#
# 초반에 별로다. 따른 생각이니 죽음의 평가했을때 하품하고 돈내고 아직 SENTENCE_START 없는데 진짜 SENTENCE_START 참석이라니 있었는데..마지막은 감독이 영화라는 두고
#
# 안돼 시리즈중 주변 공감전혀안됨 두시간 SENTENCE_START 다 아 그냥 후회막급 항상 저 점수도

# %% [markdown]
# <br><br><br><br>
# # Evaluation & Challenging
# <hr style="border-color:#ff9900">
