# %% [markdown]
# -

# %% [markdown]
# <h1><center>[[---- Bad Comment Generator using RNN ----]]</center></h1>
# <h3><center>( 발표자료 : http://www.slideshare.net/shuraba1/bad-comment-generator-using-rnn )</center></h3>
# <br><br>
# <h3><p style="text-align:right">발표자 : 송치성(https://www.facebook.com/shuraba)</p></h3>

# %% [markdown]
# # Goal :
# <hr style="border-color:#ff9900">
# ## 영화 악평들로 학습하는 Language Modeling을 통해 '악평생성기'를 만들어보자!

# %% [markdown]
# <br><br><br><br>
# # Step 1. Data Preprocessing
# <hr style="border-color:#ff9900">

# %% [markdown]
# - 데이터를 RNN으로 학습하기 좋은 형태로 전처리.

# %%
import os
import time
import random
import itertools
import pickle
import collections

import numpy as np
import tensorflow as tf
from tensorflow.python.ops import rnn_cell
from tensorflow.python.ops import seq2seq

# %% [markdown]
# ## 0. Load Text Data & Attach Sentence Start/End Token
# - 실습에 사용할 데이터 불러옴.
# - 실습데이터 : 평점 상위권 영화의 리뷰 중 악평들..

# %%
DATA_DIR = "./data"
INPUT_FILE = os.path.join(DATA_DIR, "bad_reviews.txt")

# %% [markdown]
# - 우리의 목적 : 이런 꼴이 되도록 만들자!
#     - 토크나이징 하기 전에 문장(리뷰)의 시작과 끝에 각각 특정 토큰을 붙임.
#     - 문장(리뷰)의 첫번째 단어와 마지막 단어는 어떤게 올지 학습이 가능.
# ![RNN example](img/RNN_example.png)

# %%
sentence_start_token = "SENTENCE_START"
sentence_end_token = "SENTENCE_END"

# %%
with open(INPUT_FILE, "r") as f:
    sentences = ['%s %s %s' % (sentence_start_token, line.strip(), sentence_end_token) for line in f.readlines()]

# %%
sentences[:8]
# Out:
# ['SENTENCE_START 극장에서 돈내고 보긴아깝다 SENTENCE_END',
#  'SENTENCE_START 진짜,, SENTENCE_END',
#  'SENTENCE_START 훌륭하지만 비약적인 스토리 SENTENCE_END',
#  'SENTENCE_START OOO야.. 아 진짜 후회했음 후회막급 ! ! 오빠테 욕먹었음... -_- SENTENCE_END',
#  'SENTENCE_START 잼씀 SENTENCE_END',
#  'SENTENCE_START 지 랄들 하세요 이민자들의 성공기 허울좋은 명분일뿐이고 마피아비판도 명분이고 마피아미화란 미화는 다 시키고 똥폼잡는작품 방구석에 처박혀서 이런거나보고 멋있다고 아우성는 저능아들을 위한작품 세상을 제대로알고 똑바로봐라 SENTENCE_END',
#  'SENTENCE_START 1~3편보고솔직히재미없다 SENTENCE_END',
#  'SENTENCE_START 진짜 심하게 지루하다 SENTENCE_END']

# %%
# 전체 리뷰 갯수
len(sentences)
# Out:
# 128173

# %%
# 실습을 위한 슬라이싱.
sentences = sentences[:1000]

# %%
len(sentences)
# Out:
# 1000

# %% [markdown]
# ## 1. Tokenize Sentences into words
# - __토큰화(Tokenize)__ : 자연어처리를 하기위하여 텍스트를 기본단위로 나누는 과정.
# - 어절 단위 vs 형태소 단위
#     - 본 실습에서는 __어절__단위로 토큰화. ( ex 동해물과/백두산이/마르고/닳도록 ...)
#     - 어절단위 토큰화 장단점:
#         - 장점: __빠르다__, 간단하다
#         - 단점: __교착어에 취약__ (ex. "치킨을" != "치킨이", "봤다" != "봤었다")
# - 이번 실습에서는 한 리뷰가 한 문장이라고 가정.

# %%
from konlpy.tag import Mecab
tagger = Mecab()
sample_review = "극장에서 돈내고 보긴 아깝다."

# %%
# 형태소 단위 Tokenizing
["%s/%s" % (word,pos) for word,pos in tagger.pos(sample_review)]
# Out:
# ['극장/NNG',
#  '에서/JKB',
#  '돈/NNG',
#  '내/VV',
#  '고/EC',
#  '보/VX',
#  '긴/ETN+JX',
#  '아깝/VA',
#  '다/EF',
#  './SF']

# %%
# 어절 단위 Tokenizing
sample_review.split()
# Out:
# ['극장에서', '돈내고', '보긴', '아깝다.']

# %%
sentences_tokenized = [sent.split() for sent in sentences]
sentences_tokenized[:8]
# Out:
# [['SENTENCE_START', '극장에서', '돈내고', '보긴아깝다', 'SENTENCE_END'],
#  ['SENTENCE_START', '진짜,,', 'SENTENCE_END'],
#  ['SENTENCE_START', '훌륭하지만', '비약적인', '스토리', 'SENTENCE_END'],
#  ['SENTENCE_START',
#   'OOO야..',
#   '아',
#   '진짜',
#   '후회했음',
#   '후회막급',
#   '!',
#   '!',
#   '오빠테',
#   '욕먹었음...',
#   '-_-',
#   'SENTENCE_END'],
#  ['SENTENCE_START', '잼씀', 'SENTENCE_END'],
#  ['SENTENCE_START',
#   '지',
#   '랄들',
#   '하세요',
#   '이민자들의',
#   '성공기',
#   '허울좋은',
#   '명분일뿐이고',
#   '마피아비판도',
#   '명분이고',
#   '마피아미화란',
#   '미화는',
#   '다',
#   '시키고',
#   '똥폼잡는작품',
#   '방구석에',
#   '처박혀서',
#   '이런거나보고',
#   '멋있다고',
#   '아우성는',
#   '저능아들을',
#   '위한작품',
#   '세상을',
#   '제대로알고',
#   '똑바로봐라',
#   'SENTENCE_END'],
#  ['SENTENCE_START', '1~3편보고솔직히재미없다', 'SENTENCE_END'],
#  ['SENTENCE_START', '진짜', '심하게', '지루하다', 'SENTENCE_END']]

# %%
# 전체 문장을 하나의 리스트로 변환.
text_tokenized = list(itertools.chain(*sentences_tokenized))
text_tokenized[:30]
# Out:
# ['SENTENCE_START',
#  '극장에서',
#  '돈내고',
#  '보긴아깝다',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '진짜,,',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '훌륭하지만',
#  '비약적인',
#  '스토리',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  'OOO야..',
#  '아',
#  '진짜',
#  '후회했음',
#  '후회막급',
#  '!',
#  '!',
#  '오빠테',
#  '욕먹었음...',
#  '-_-',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '잼씀',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '지']

# %% [markdown]
# ## 2. Word Indexing and Remove Infrequent Words
# - 각 단어에 고유의 인덱스(id)를 붙임.
# - 인덱스를 통한 one-hot vector 형태로 단어 표현. (cf. [Vector Representations of Words](https://www.tensorflow.org/versions/r0.8/tutorials/word2vec/index.html) )
# - 인덱스는 빈도순으로 줌.
# - 빈도수가 낮은 단어 제거 (기준 : 단어 사전 사이즈).

# %%
# 단어 개수 Threshold
vocab_size = 3000

# %%
# vocabulary 생성
word_freq = collections.Counter(text_tokenized)
vocab = word_freq.most_common(vocab_size - 1)

# %%
# 전체 단어 갯수
len(vocab)
# Out:
# 2999

# %%
# 상위 빈도 10개 
vocab[:10]
# Out:
# [('SENTENCE_START', 1000),
#  ('SENTENCE_END', 1000),
#  ('너무', 62),
#  ('진짜', 55),
#  ('영화', 48),
#  ('정말', 40),
#  ('평점이', 31),
#  ('그냥', 29),
#  ('영화.', 23),
#  ('다', 20)]

# %%
# 하위 빈도 10개
vocab[-10:]
# Out:
# [('아이고', 1),
#  ('영화는...이라는', 1),
#  ('새것이었던', 1),
#  ('관람후', 1),
#  ('비추!!!', 1),
#  ('연기자는', 1),
#  ('최악임', 1),
#  ('무엇인지...', 1),
#  ('결여되고', 1),
#  ('한물', 1)]

# %%
# 단어 분포 확인.

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.charts.attributes import CatAttr
from bokeh.charts import Dot
# from bokeh.models import ColumnDataSource, LabelSet
# from bokeh.models import HoverTool
output_notebook() # 주피터 노트북에서 볼때,
#output_file("chart.html") # 주피터노트북이 아닌 html로 출력할때,
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b388dedc-0876-4eca-b141-4db2af9e3482">Loading BokehJS ...</span>
#     </div>

# %%
data = {
    'token': [ ele[0] for ele in vocab][2:500],
    'freq': [ ele[1] for ele in vocab][2:500]
}
tools = "pan,wheel_zoom,box_zoom,reset,resize"

dots = Dot(data, values='freq', label=CatAttr(columns=['token'], sort=False), legend=False, title="Python Interpreter Sampling", width=600)

show(dots)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e49020f6-50d9-4358-a36d-9ba58a3ad699"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e49020f6-50d9-4358-a36d-9ba58a3ad699").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e49020f6-50d9-4358-a36d-9ba58a3ad699");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e49020f6-50d9-4358-a36d-9ba58a3ad699' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f8d5949b-b863-4204-9a42-9b90abd8a793":{"roots":{"references":[{"attributes":{"data_source":{"id":"66c20cce-32e4-4e09-8bc8-b1a8be002cda","type":"ColumnDataSource"},"glyph":{"id":"5a5cffc2-b3c2-4d20-a54f-c4b975c8e75f","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9dc63142-3d35-42b8-8a4e-4e7a5dfbf92a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5eda7b73-3b88-4658-a595-c99b228cd440","type":"ColumnDataSource"},"glyph":{"id":"3a2ccdb8-19bd-4576-aed4-4244c56ca5bc","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c2bc2dda-014f-4701-841b-0e27985190d6","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"53c9bf83-3794-4ea7-9eb8-f7d9a0f50b46","type":"ColumnDataSource"},"glyph":{"id":"0a9d1cfd-cc46-4854-a15d-88440d2b7147","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f88bc3c7-855e-41f7-a2e0-e44b7b2c1065","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","y","height","label","fill_alpha","width"],"data":{"chart_index":[{"token":"\uc804\uac1c\uac00"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":[{"token":"\uc804\uac1c\uac00"}],"line_alpha":[1.0],"line_color":["#f22c40"],"token":["\uc804\uac1c\uac00"],"width":[0.8],"x":["\uc804\uac1c\uac00"],"y":[1.0]}},"id":"ed3d9b43-ac28-4ea7-bcb5-8205cddd02e9","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","y","height","label","fill_alpha","width"],"data":{"chart_index":[{"token":"\uc911\uac04"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":[{"token":"\uc911\uac04"}],"line_alpha":[1.0],"line_color":["#f22c40"],"token":["\uc911\uac04"],"width":[0.8],"x":["\uc911\uac04"],"y":[1.5]}},"id":"b8209b91-82cd-473f-a33d-5bf9fea8bfab","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"c7b757ff-f198-40b5-8d69-58a9f7a57718","type":"Circle"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","y","height","label","fill_alpha","width"],"data":{"chart_index":[{"token":"\uc601\ud654,"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":[{"token":"\uc601\ud654,"}],"line_alpha":[1.0],"line_color":["#f22c40"],"token":["\uc601\ud654,"],"width":[0.8],"x":["\uc601\ud654,"],"y":[1.0]}},"id":"76e7d885-6c38-444b-90d5-e8a8e5b3584f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"bdcad844-6dea-4c28-91ba-812f243787f2","type":"Circle"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"f52d44f4-8d5d-466c-bbf6-90828b4a95f6","type":"Circle"},{"attributes":{"callback":null,"column_names":["color","line_alpha","line_color","x","y","height","label","fill_alpha","width"],"data":{"chart_index":[{"token":"\uc131\uc6b0\ub97c"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":[{"token":"\uc131\uc6b0\ub97c"}],"line_alpha":[1.0],"line_color":["#f22c40"],"token":["\uc131\uc6b0\ub97c"],"width":[0.8],"x":["\uc131\uc6b0\ub97c"],"y":[1.5]}},"id":"c87010cf-d106-42f6-a0f6-0f81ad7764eb","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#f22c40"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"height"}},"id":"04e17fb ...

# %%
# 저빈도 단어는 "UNKNOWN_TOKEN"로 처리
unknown_token = "UNKNOWN_TOKEN"

# %%
def build_vocab(sentences, vocab_size, unknown_token):
    # vocab
    word_freq = collections.Counter(text_tokenized)
    print("전체 단어 개수 : ", len(word_freq.items()))
    vocab = word_freq.most_common(vocab_size - 1)
    
    # Mapping from index to word
    id2word = [x[0] for x in vocab]
    id2word.append(unknown_token) # 사전에 없는단어 처리.
    # Mapping from word to index
    word2id = {w: i for i, w in enumerate(id2word)}

    return (word2id, id2word)

# %%
word2id, id2word = build_vocab(text_tokenized, vocab_size, unknown_token)
# Out:
# 전체 단어 개수 :  4724

# %%
word2id
# Out:
# {'지루했음': 651,
#  '나간': 418,
#  '단편': 652,
#  '였습니다': 653,
#  '캐릭터에': 654,
#  '아까워': 182,
#  '존나': 655,
#  'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ': 681,
#  '만드니?': 657,
#  '시간아깝다': 658,
#  '하지않나': 659,
#  'ㅓ': 308,
#  '별로였다..내': 662,
#  '좋다': 663,
#  '9점이': 664,
#  '1시간30분': 2736,
#  '긴장감이': 666,
#  '느낌.': 183,
#  '이해못하는': 667,
#  '늘어짐...': 668,
#  '참아내느라': 669,
#  '무지하게': 670,
#  '20년': 671,
#  '닮았다는건지...': 672,
#  '스탈.': 673,
#  '몇개있고...남자친구는': 674,
#  '비어버린': 675,
#  '짜내려고': 676,
#  '지루의': 677,
#  '재미없음ㅡㅡㅡㅡㅡㅋㅋ': 823,
#  '꼰대가': 678,
#  '여배우가': 679,
#  '명작이었음~!': 680,
#  '내용이라든가....': 656,
#  '왕자를': 682,
#  '꼭': 190,
#  '생각하심??': 683,
#  'UNKNOWN_TOKEN': 2999,
#  '억지네': 684,
#  '영': 685,
#  'u': 686,
#  '..;;': 687,
#  '학생시절': 688,
#  '성공기': 689,
#  '전개도': 690,
#  '만들었네요': 691,
#  '특이할것': 692,
#  '복수': 693,
#  '여자판': 694,
#  '왜보냐~': 695,
#  '루이의': 696,
#  '재미없다.': 184,
#  '정말지루하고': 698,
#  '적당.평점': 699,
#  '하는건지': 700,
#  '내': 58,
#  '연락도씹어요!': 701,
#  '않는다는것은': 998,
#  '처음엔': 703,
#  '문제임..1,2,3편까지가': 704,
#  '안남': 705,
#  '감독들이': 706,
#  '기대': 101,
#  '같지만...이런': 707,
#  '돋는다루의': 709,
#  '마피아비판도': 711,
#  '상승이미지가': 712,
#  '좋을': 713,
#  '저리가라!!': 714,
#  '토나오네요': 715,
#  '처음의': 716,
#  '억지스러운데': 718,
#  '속았다...중간에보다': 719,
#  '안된다.': 720,
#  '르네': 721,
#  '총으로쏘냐ㅋㅋ개말도안되게꾸며났네ㅋㅋ그리고': 722,
#  '뒷배경에': 723,
#  '못봐주겠네...': 724,
#  '재밌다.': 726,
#  '해주는': 727,
#  '분발하자': 728,
#  '웃음': 729,
#  '정말재밋어요': 730,
#  '얼마': 732,
#  '선택': 2947,
#  'ㅎㅎㅎ': 734,
#  '짜증나고,': 735,
#  '가서': 736,
#  '안되게': 737,
#  '못믿겠다.': 738,
#  '졸리연기만해라': 1195,
#  '자격이': 739,
#  '되어있다.': 740,
#  '여자': 349,
#  '이런건지.': 1359,
#  '안타깝다': 746,
#  '사랑은': 747,
#  '빡칠정도로': 748,
#  '명작이다하니': 749,
#  '스릴러': 750,
#  '울': 312,
#  '오늘학교에서': 751,
#  '수용소에서': 753,
#  '그런가?': 313,
#  '철이': 2870,
#  '10점준놈들': 2751,
#  '좋아': 757,
#  '주제로': 758,
#  '-_-': 102,
#  '..': 59,
#  '우리나라는': 759,
#  '오버연기': 760,
#  '유치짬뽕수준': 761,
#  '허락된': 762,
#  '2시간짜리드라마': 763,
#  '15년전': 764,
#  '거제도를': 765,
#  '뇌가': 1398,
#  '줄거리나': 768,
#  '13세': 315,
#  '황당함...': 769,
#  '대단히': 770,
#  '졸작중의졸작': 771,
#  '최고로': 772,
#  '오히려': 316,
#  '시키는건가?': 773,
#  '구체적': 774,
#  '2를': 1370,
#  '잠잤다': 776,
#  '결말도': 777,
#  '재미있다.': 778,
#  '봐도': 185,
#  '국어사전읽어주는느낌.보면안다': 782,
#  '이해가': 103,
#  '소설하고': 783,
#  '않을까싶네요.': 2757,
#  '알엇내': 785,
#  '안보인다': 786,
#  '난해하다': 787,
#  '친구로서의': 788,
#  '흠이지만.': 789,
#  'OO들.': 790,
#  '40자평보고': 791,
#  '기분만': 2039,
#  '이영화가': 186,
#  '큰': 128,
#  '특히나': 2834,
#  '성우도': 793,
#  '영화!': 794,
#  '죽는줄': 317,
#  '만드는게': 795,
#  '멋있다고': 796,
#  'ㅈㄹ?OO': 797,
#  '장난?': 798,
#  '아쉽다.': 799,
#  '표현된': 800,
#  '짱공유가서': 801,
#  '심리학적으로는': 1615,
#  '잤어요.': 1119,
#  'OO': 805,
#  '루가': 806,
#  '될': 807,
#  '무슨': 72,
#  '존나게': 318,
#  '스네이프': 808,
#  '그대로': 188,
#  '빅의': 809,
#  '몰입이': 393,
#  '되게': 811,
#  '못미친...': 812,
#  '주인공은': 129,
#  '부족하여': 1710,
#  '평점이높음?': 818,
#  '죽인것도': 819,
#  '핵': 820,
#  '좋았으나': 327,
#  '남자탓이구만': 822,
#  '떡': 824,
#  '변함없다.': 826,
#  '슬프게': 827,
#  '비해': 189,
#  '기법은': 972,
#  '없는데': 829,
#  '참담한': 830,
#  '개망작이었음': 831,
#  'HDTV문학관이다.': 832,
#  '손발': 833,
#  '19세': 834,
#  '꿈꾸는': 835,
#  '이거보면': 836,
#  '바꾸는': 838,
#  '아니라서': 839,
#  '먼저': 840,
#  '드라마팬들은': 841,
#  '비교해보라.': 842,
#  '않네가장': 843,
#  '망치지': 1864,
#  '찜찜해': 845,
#  '자품이니깐': 846,
#  '아우~': 847,
#  '터무니없는': 848,
#  '올해': 850,
#  '1점..': 851,
#  '영화다': 852,
#  '재미없었음..ㅠㅠ': 853,
#  '죽여': 1909,
#  '눈물콧물정액': 855,
#  '예상치못한반전이라고들해서': 856,
#  '시간아까워': 857,
#  '찾아': 859,
#  '딴거라도': 946,
#  '아까웠다.': 861,
#  '분위기다깬다': 862,
#  '그뿐.': 863,
#  '쇼쇼쇼': 865,
#  '르네젤위거그만깝치고': 866,
#  '없을': 867,
#  '재미가': 73,
#  '않아': 868,
#  '이유': 869,
#  '학생인': 871,
#  '몇번': 872,
#  '예상': 873,
#  '개연성이': 874,
#  '편집하고': 875,
#  '기쁨인척': 876,
#  '억지스럽게': 877,
#  '떨어뜨리자': 878,
#  '끝나는': 595,
#  '지브리애니': 880,
#  '조심혀': 881,
#  '건지': 882,
#  '돼지를': 883,
#  '명가': 884,
#  '주성치의': 885,
#  '그럴': 886,
#  '자빠졋냐': 887,
#  '이하가': 321,
#  '자게': 888,
#  '나오던': 889,
#  '0점줘도': 890,
#  '걸작인가요?+ㅇ+': 891,
#  '뿐.': 892,
#  '여건에': 893,
#  '보니까': 894,
#  '둑겠다~~': 895,
#  '웃기네..': 896,
#  '쌔고쌨는데ㅉㅉㅉ': 897,
#  '그이하입니다': 898,
#  '현실은': 899,
#  '후회된다': 900,
#  '크게': 432,
#  '결과는': 902,
#  '제니퍼': 903,
#  '여주의': 361,
#  '박차고': 904,
#  '다시보고싶음': 906,
#  '불륜': 191,
#  '억지스럽다': 907,
#  '이런게': 908,
#  '여자티가': 909,
#  '글쎄요': 910,
#  '너무현실적으로': 912,
#  '얼마나': 104,
#  '보시길': 914,
#  '보여주지': 915,
#  '뭐이딴게': 916,
#  '편.': 917,
#  '아~': 918,
#  '드러날': 919,
#  '못한영화': 920,
#  '눈치보여': 1719,
#  '여자주인공배우': 923,
#  '해달라.누가': 924,
#  '자기위안.': 926,
#  '자체가': 130,
#  '전개가': 322,
#  '더빙': 294,
#  '장면에서': 441,
#  '때마다': 929,
#  '패밀리라는': 930,
#  '짜증난다': 2827,
#  '길어서인가..약간운': 932,
#  '만화라그런가': 933,
#  '가면': 934,
#  '낫다.': 235,
#  '쪽바리의': 2416,
#  '예술성도': 938,
#  '개소리는': 939,
#  '졸도한다': 941,
#  '이보다는': 943,
#  '국민': 2073,
#  '초등학생의': 945,
#  '관심있으면': 948,
#  '떨어질때도': 949,
#  '억지로봄': 950,
#  '말만쓰면10점올라가자나': 951,
#  '봤었던': 952,
#  '묘사.그에반해': 953,
#  '뻔하고더럽게잼없음....': 954,
#  '12편을보고이정도평점은아니다': 956,
#  '전문가평점': 957,
#  '영화임': 2075,
#  '없는편이라': 959,
#  '높당': 960,
#  '만들어': 323,
#  '영화...연출력도': 961,
#  '불륜영화됨': 962,
#  '할머니들에게': 963,
#  '로코가': 964,
#  '영화라는': 2781,
#  '주려다가': 967,
#  '들어있는척': 968,
#  '타당성이': 969,
#  '공부': 970,
#  '위한': 60,
#  '늘어놓은': 1863,
#  '처음부터': 192,
#  '개봉해??': 974,
#  '맞추는': 975,
#  '아니라': 325,
#  '포장한': 326,
#  '깨주기를': 976,
#  '배우활동만': 977,
#  '졸려나무다': 978,
#  '별로다...': 319,
#  '잼없었는데````````': 980,
#  '해소되지': 981,
#  '활동한다는': 983,
#  '재미업는': 984,
#  '겁쟁이로': 985,
#  '허세영화를': 986,
#  '별로': 23,
#  '소리': 780,
#  '싫어했음': 988,
#  '멋짐': 989,
#  '중간까지': 990,
#  '높은듯...': 992,
#  '슈퍼사이즈미나': 993,
#  '이변은': 994,
#  '짜증까지도': 995,
#  '별로다..': 474,
#  '휴일': 479,
#  '캐릭터': 193,
#  '봐서': 1000,
#  '대표적': 1001,
#  '무더기': 1003,
#  '남편한테': 1004,
#  '보나요?': 1005,
#  '영화!!': 328,
#  '속았다.....': 1007,
#  '감독에게': 1008,
#  '이런영화': 329,
#  '표현을': 1009,
#  '한국': 194,
#  '작품이다.이': 1010,
#  '감독이생각이': 1011,
#  '허지웅이': 1012,
#  '난투극이': 1013,
#  '오랜만이네.': 1014,
#  '리얼리티.': 1015,
#  '기억에': 330,
#  '독일놈들도': 2933,
#  '가관이네요..평이': 1677,
#  '끝까지': 331,
#  '많구만;;': 2476,
#  '끌고영화의': 1019,
#  '유일한,': 1020,
#  '일편으로충분했을듯': 1021,
#  '않는것이': 1022,
#  '영화~': 1024,
#  '전개에': 1025,
#  '따뜻해지고': 1026,
#  '환경': 1027,
#  '민주주의의': 1028,
#  '죽자는': 1029,
#  '영!!': 1030,
#  '맥퀸': 1033,
#  '신경을': 1034,
#  '초반에': 1035,
#  '그녀를': 1036,
#  '영화에': 121,
#  '미국의': 1039,
#  '자식교육에': 1040,
#  '할수': 131,
#  '아쉽다': 502,
#  '쩝': 1043,
#  '좋은감독이': 1044,
#  '남을': 332,
#  '봐야만한다.......사실': 1045,
#  '졸작': 75,
#  '건': 132,
#  '만들긴했네요': 1046,
#  '비롯해서': 1049,
#  '느끼눼.남주': 1050,
#  '주제는': 333,
#  '작가가': 1053,
#  '코메디': 1054,
#  '완전모범': 1055,
#  '-_-;': 1056,
#  '영화보면서': 1059,
#  '모르겠다': 1061,
#  '보이지도': 1062,
#  '우습게': 1063,
#  'OO뻔': 1064,
#  '7점대가': 1065,
#  '동행할': 1066,
#  '<스카이폴>과': 1067,
#  '지겨워': 133,
#  '감정선이': 1071,
#  '쓰레기...': 2848,
#  '원조격': 1074,
#  '봤네;': 1075,
#  '감흥이': 1076,
#  '영어발음.': 1078,
#  '점': 2100,
#  'OOO기': 1080,
#  '객관적으로': 1081,
#  '못한영화...그립다': 1082,
#  '허울': 1083,
#  '졸면서': 1085,
#  '길게늘여놔서': 1086,
#  '더좋음더빙': 1087,
#  '하...기대': 1088,
#  '잘못캐스팅한듯..': 2802,
#  '첫날': 1090,
#  '어색하네': 1091,
#  '1편~2편': 1092,
#  '일본특유의': 1094,
#  '짱OO들과': 1095,
#  '남자배우들': 1096,
#  '8점이라니': 1097,
#  '주구장창': 754,
#  '엉?': 1099,
#  '부르는거': 1100,
#  '연출.': 1101,
#  '다큐멘터리는': 1102,
#  '옛날': 1103,
#  '쓰레기중에': 1104,
#  '야': 196,
#  '재미없었어요ㅠㅠ': 1105,
#  '봤습니다.': 1106,
#  '평타.': 1107,
#  '..속았다..이런유치한영화오랜만이었다': 1109,
#  '성물중': 1111,
#  '나가는': 1112,
#  '만화영화로': 781,
#  '억지스럽고': 335,
#  '세상에': 1115,
#  '기분': 91,
#  '좋아하는': 336,
#  '영화드럽게': 1117,
#  '예전것보다': 1118,
#  '깨나': 1120,
#  '감정선도': 2258,
#  '스럽네...!!!': 1122,
#  '극적(각색)이고,': 1123,
#  '핵노잼진짜이영화보다가지루해서잠왔음': 1125,
#  '느낌?': 1126,
#  '기대했는데': 337,
#  '않은거지': 1127,
#  '제': 1128,
#  '쓴거같네!': 1129,
#  '줄서잇는': 1130,
#  '관객': 339,
#  '평점도': 1131,
#  '검정고무신': 1132,
#  '해리포터와': 340,
#  '책에비해별로': 1133,
#  '우왕ㅋ재미는': 1134,
#  '영화로': 105,
#  '못한다.': 1135,
#  '실화라는': 1136,
#  '와타나베': 1137,
#  '안정된': 1138,
#  '인내갖고': 1139,
#  '없어;;': 1141,
#  '왔다.': 1142,
#  '불호': 1143,
#  '로멘스': 1144,
#  '했던': 1146,
#  '봤다면': 1147,
#  '별로없어여': 1148,
#  '이태리(?)에서': 1149,
#  'ㅡㅗㅡ': 1150,
#  '돈주고': 197,
#  '내기준에': 1152,
#  '살다가': 1153,
#  'going': 2810,
#  '그거': 341,
#  '상영을': 1156,
#  '대박인': 1157,
#  '짜증나는건': 1158,
#  '자막': 1159,
#  '빨리': 1161,
#  '화면': 1162,
#  '2점씩이나': 1163,
#  '나': 342,
#  '돌아오고,': 1164,
#  'ㅇ벗넹?': 1165,
#  '미국인과': 1166,
#  '만드는,,,조악한': 1167,
#  '인간의': 134,
#  'ㅠㅠ': 111,
#  '실망.2편의브리짓': 2815,
#  '지겹다고': 1171,
#  '기대가': 1173,
#  '지루한스토리가': 1174,
#  '1/3': 742,
#  '아닌': 135,
#  '시간낭비ㅡㅡ': 1177,
#  '안나도록': 1178,
#  '적당...': 1179,
#  '재미없어서': 343,
#  '엔딩만은': 1180,
#  '바탕으로': 344,
#  '유지태.아': 1181,
#  '답답했네..바보들인가..평점': 1182,
#  '잤엄': 1183,
#  '노래를': 1184,
#  '똑바로봐라': 1185,
#  '정상이냐': 1186,
#  '중간': 198,
#  '전에': 1187,
#  '실화': 1188,
#  'M창': 1189,
#  '생략해버림;': 1190,
#  '전형성': 1191,
#  '지루하다.': 579,
#  '확실하게': 1192,
#  '금지해야하지': 1193,
#  '완전유치에': 1194,
#  '의미를': 311,
#  '뒷부분이.....': 1196,
#  '싸이코패스가': 1197,
#  '보러갑니다.': 1198,
#  '못합니다.': 1199,
#  '기분이': 106,
#  '그래서': 540,
#  '속았다.': 345,
#  '이딴게': 1202,
#  '.': 199,
#  '비웃음으로': 2822,
#  '결말은': 1204,
#  '생겼다': 1205,
#  '게다가': 1206,
#  '않는': 346,
#  '해그리드의품에서': 1207,
#  '제대로된': 347,
#  '가져다가': 1208,
#  '보는느낌': 991,
#  '때문이다..ㅋㅋ': 1210,
#  '옛': 1211,
#  '보기에': 1212,
#  '내면에': 1213,
#  '유치하고': 1214,
#  '괜찮았는데..이번작은': 1215,
#  '만들수가': 1216,
#  '잤다': 200,
#  '한계는': 1217,
#  '단순한': 1218,
#  '먼내용이야': 1219,
#  '빅이': 1220,
#  '희생시키지': 1221,
#  '많아서': 348,
#  '대화들': 744,
#  'ㅡ.ㅡㅋㅋ': 1223,
#  '계속해서': 1224,
#  'ㅋㅋ보지마세요': 1225,
#  '보고난후가': 1227,
#  '또는': 1228,
#  '야장난하냐': 1231,
#  '여자가': 201,
#  '지루하기그지없다....평점믿고': 1232,
#  '때문일까': 1233,
#  '관객을': 1234,
#  '학대해도': 1235,
#  '저로선': 350,
#  '졸리씨?': 2826,
#  '어거지': 1238,
#  '-_': 1241,
#  '아깝다...': 1242,
#  '자녀가': 1243,
#  '지루했다.-.-;': 1244,
#  '무식하고': 1245,
#  '실망했다': 1246,
#  '아무': 351,
#  '높다.': 352,
#  '갖다붙이려고': 1247,
#  '권력을': 2127,
#  '말리지않은것도': 1249,
#  '년이랑': 1250,
#  '이명박때문이': 2828,
#  '영화는': 14,
#  '감흥이떨어짐나체사진들은ㄹ혐오스러움.영화를': 1252,
#  '구성.......': 1253,
#  '또': 76,
#  '시간은': 1254,
#  '또다시': 1255,
#  '머리...': 1256,
#  '남자': 334,
#  'ㅡㅡ왜만들었어?이병헌떄매봤다진짜': 1259,
#  '미화한': 1261,
#  '해리': 1262,
#  '만나러갈때도': 1263,
#  '이게8점??6점까지': 1264,
#  '영화-_-': 1265,
#  '오~브리짓!': 1267,
#  '엄청': 107,
#  '촬영과': 1269,
#  '보고.': 1270,
#  'OOO..': 1271,
#  '포스터가': 1272,
#  '쓰레기를': 1273,
#  '여자지만': 1274,
#  '무서운': 1275,
#  '이걸': 54,
#  '어디에?': 1277,
#  '이거보다': 1279,
#  '안듬': 353,
#  '뛰어난': 355,
#  '저것도': 1281,
#  '높다-': 1283,
#  '다': 9,
#  '잼있지는': 1284,
#  '무서운것도': 922,
#  '느껴졌어요': 1286,
#  '세상을': 356,
#  '두고': 1287,
#  '든': 1288,
#  '완전OOO기영화!!!!': 1289,
#  '역': 1290,
#  '이런영화를': 1291,
#  '제미있을까요?': 1293,
#  '못생겼다.': 1294,
#  '절망적으로만': 1295,
#  '지루하다.재미없다.졸리다.': 1296,
#  '웃기지도': 2837,
#  '지닌': 1298,
#  '과장함': 1299,
#  '이런식으로': 1300,
#  '영화의': 202,
#  '칸': 1301,
#  ',': 357,
#  '못했기': 1302,
#  '많이안보고': 1303,
#  '불륜같은거': 1304,
#  '여자주인공도': 1305,
#  '피': 1306,
#  '안에서': 1307,
#  '서울말투를쓰는부산': 1308,
#  '식상하고': 1309,
#  '재미없어': 203,
#  '여': 2983,
#  '안하려다': 1313,
#  '극한의': 1314,
#  '1위를': 1315,
#  '해리와': 2839,
#  '첨엔': 1317,
#  '티비드라마': 1318,
#  '현실적이니': 1319,
#  '쓰렉': 1320,
#  '와타나베를': 1321,
#  '의리는': 1322,
#  '수요일': 1323,
#  '생각보다': 1324,
#  '못생기고': 1325,
#  '수': 24,
#  '안드는': 1326,
#  '말까지떠오른다': 1327,
#  '잼씀': 2918,
#  '2일': 1328,
#  '배우는배우만하는게맞다는생각만들더라일부러억지감동만들어내려고하는거같앗고': 1329,
#  '주제도': 1330,
#  '장난?낚였어썅': 1332,
#  '손발오그라드는': 1334,
#  '있는거겠죠.이런류의': 1335,
#  '것..': 1336,
#  '오후': 1337,
#  '자기만의': 1338,
#  '다를바': 1339,
#  '한다': 1340,
#  '여운을': 1342,
#  '망쳐노면;;': 937,
#  '최악인듯': 1343,
#  '=_=재미없었다.': 1344,
#  '취향차이겠지만..뻔한소재': 1345,
#  '에피소드의': 1346,
#  '녹아내려': 1347,
#  '영화,': 358,
#  '전개,': 1349,
#  '머시기': 1350,
#  '뿐이다.이게': 1351,
#  '이런건': 310,
#  '더빙,': 1353,
#  '호그와트': 1354,
#  '바로': 1355,
#  '성우': 1356,
#  '별로였음요ㅠ': 710,
#  '마피아물과': 1358,
#  '주는건': 745,
#  '사람인듯.정말정말': 1818,
#  '좋아할만함^^': 1361,
#  '만들었을까.': 1362,
#  '슬랩스틱코메디': 2142,
#  '맨앞에': 1364,
#  '한심하고유치한영화!': 1365,
#  '적당': 1366,
#  '경민이가': 1367,
#  '드러워': 1368,
#  '못봤는데,고객센터에서': 1369,
#  '같아': 775,
#  '볼만했으나': 1371,
#  '키워봤자': 1372,
#  '뭔가': 136,
#  '깝치는': 1374,
#  '봤으나': 1375,
#  '잡치는': 1376,
#  '개지루': 1377,
#  '청소년': 1379,
#  '70년대': 544,
#  '천하에': 1381,
#  '흥미롭지만': 359,
#  '그는': 1382,
#  '보세요.-_-아님': 1383,
#  '별로...': 1384,
#  '안되고..': 860,
#  '중에': 295,
#  '명분이고': 1387,
#  '맘에안들구': 870,
#  '거': 360,
#  '순': 1390,
#  '시간때우긴': 1391,
#  '멍하다.': 1392,
#  '문화를': 1393,
#  '없다': 33,
#  '그리고': 137,
#  '저래?': 1394,
#  '길게': 1395,
#  '되질': 1396,
#  '사냐?': 1397,
#  '나빴던': 1399,
#  '정말...솔직히': 1400,
#  '있냐?': 1401,
#  '이야기라고': 1402,
#  '중요하다': 1403,
#  '나만': 1404,
#  '정도': 1405,
#  '화가': 1406,
#  '결점들?"': 971,
#  '별로;;': 1408,
#  '상기': 1410,
#  '나을것': 1411,
#  '표현이': 2392,
#  '원망하고싶다.': 1415,
#  '으이구': 1416,
#  '흐름이': 1417,
#  '캐망...': 1418,
#  '봤는지가': 1419,
#  '이병헌': 362,
#  '욕설과': 1420,
#  '1점도': 77,
#  '억지스러웠다...': 2891,
#  '영화냐...초딩용': 1421,
#  '엄마한테': 1475,
#  '이런': 10,
#  '높게나와서리...': 1424,
#  '누구냐???': 1113,
#  '한국인데': 1427,
#  '사람이': 363,
#  '억지': 1428,
#  '처음': 116,
#  '반지의제왕보다못합니다.아바타랑': 1429,
#  '맘이': 2149,
#  '사용해': 1430,
#  '위해': 366,
#  '별로였다.': 1431,
#  '앉고': 1432,
#  '한국도': 1433,
#  '아무리': 1434,
#  '연기하는것과': 1435,
#  '지루지루': 1437,
#  '<안경>을': 1438,
#  '어렸을쩍': 1439,
#  '3편': 1440,
#  '아줌마': 1441,
#  '적은': 1442,
#  '걍': 78,
#  '쳐주고': 1444,
#  '목소리때문에': 1445,
#  '보기엔': 367,
#  '유우': 368,
#  '드러나는.': 1446,
#  '절대보지마세요': 1447,
#  '화가난다': 1481,
#  '꺼버린영화': 1451,
#  '주려는': 1452,
#  '유치한척': 1453,
#  '만들어라': 369,
#  '정말': 5,
#  '자체는': 1454,
#  '몸매': 1455,
#  '다르내': 1456,
#  '취향이라면': 1457,
#  '안맞는': 1458,
#  '실화를': 205,
#  '잔인함': 1459,
#  '이유없음': 1460,
#  '팔지': 1461,
#  '해보았습니다)*': 1462,
#  '특별판,': 1463,
#  '본다!!': 1464,
#  '아니라면': 370,
#  '7점': 1465,
#  '전부알바들인가': 1466,
#  '말밖에는.이경영은': 1468,
#  '브리짓이랑': 1469,
#  '나와': 1470,
#  '뱀을죽이라고하지도않았는데': 1471,
#  '장면의': 1388,
#  '참': 79,
#  '배우들만': 1473,
#  '과장과': 1474,
#  '독일돼지들이': 1422,
#  '관계자들이': 1477,
#  '산동네': 1478,
#  'ㅜㅁㅜ': 1479,
#  '느낄': 1480,
#  '짱난다': 1449,
#  '단순한이야기': 2202,
#  '이쁘구먼...': 1483,
#  '잤던게아니군요...': 1484,
#  '재미없었는뎅...ㅜ.ㅜ.': 1485,
#  '그': 46,
#  '더스틴한테': 1486,
#  '재밌는주제일': 1487,
#  '비추': 39,
#  '경계해왔고': 1488,
#  '졎같네': 1489,
#  '현실가능성': 1490,
#  '할꺼다': 1530,
#  '응답하라..': 1492,
#  '주인공에게': 1493,
#  '하..난지루하던데..:::나랑은안맞는듯': 1494,
#  '어이가없다내가보기엔이간수들은본래자기성격그대로인거같은데상황에따라바뀐게아니라': 1495,
#  '감성만을': 1496,
#  '다름없이': 1497,
#  '알바들!!!!!!': 1498,
#  '실화라': 1499,
#  '완벽남': 1500,
#  '끝편까지': 1502,
#  '억울하게': 1503,
#  '스킵하거나': 1504,
#  '만들려면': 1507,
#  '굉장히': 138,
#  '영화수준은': 1509,
#  '한정판,': 2868,
#  '제로...내용도': 1511,
#  '떠날때': 1512,
#  '주말...아까운': 1513,
#  '그것이': 1514,
#  '없네': 394,
#  '같이죽자': 1517,
#  '15세': 1518,
#  '아까워서': 1519,
#  '더빙이': 1520,
#  '시작했는지,': 1521,
#  '오바심함': 1522,
#  '잘살리지못해': 1523,
#  '외국배우들': 1524,
#  '...!': 1525,
#  '연기때문에': 2166,
#  '2': 1526,
#  '졸려서...': 1527,
#  '영화...그다지..': 1529,
#  '보는': 36,
#  '기내영화로': 1531,
#  '나온': 372,
#  '왕자는': 1532,
#  '힘들었네요ㅠ': 1533,
#  '영화로서는': 1534,
#  '적힌': 1535,
#  '음악': 1536,
#  '말하려는거지....?': 1537,
#  '지루하기': 373,
#  '상황을': 374,
#  '썩어진다..': 1538,
#  '재치도': 1540,
#  '머..마지막에': 1541,
#  '보여주는': 206,
#  '살면': 1542,
#  '영화같다': 1544,
#  '얘기인지': 1545,
#  '여자랑': 1547,
#  '성우를': 292,
#  '별로에..기분더럽고': 1282,
#  '웬지': 1549,
#  '없음': 1268,
#  '없네..': 1552,
#  '젠장': 376,
#  '이런영화가': 207,
#  '평점에': 117,
#  '불편함.': 1901,
#  '현실감도': 1553,
#  '지겹다.': 1554,
#  '지루하게': 1555,
#  '무자게': 1556,
#  '애니메이션': 379,
#  '이런것이다': 1557,
#  '보다가': 47,
#  '재미를': 380,
#  '이정도?': 1558,
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ': 1562,
#  '뭐야.': 1564,
#  '안쓰님?': 1566,
#  '친히': 1567,
#  '전자에서친구들에게': 1568,
#  '것밖에': 1569,
#  '지루함.': 149,
#  '똥이네똥..TT': 1571,
#  '보여준': 1573,
#  '만들기': 430,
#  '옷': 381,
#  '감동적인': 1575,
#  '1위했다는': 1577,
#  '별내용도': 1578,
#  '고전명작의': 1579,
#  '훌륭하지만': 1580,
#  '쓰레기찌질이': 1581,
#  '부럽네..난': 1582,
#  '끈': 1583,
#  '은행원이라는데': 1584,
#  '박수를': 1585,
#  '본인이': 1586,
#  '우리': 603,
#  '저게': 1588,
#  '루저들의': 1589,
#  '해서': 208,
#  '시간만': 382,
#  '좋게말할때보지마': 1590,
#  '초딩용영화가': 1591,
#  '관람의욕': 1592,
#  '많은': 604,
#  '처음으로': 383,
#  '의도는': 1595,
#  '퉤퉤': 1596,
#  'OOO기영화.시간아까워죽는줄': 1597,
#  '손발이': 1598,
#  '할머니에': 1599,
#  '2점부터': 2175,
#  '잼없음잼없음잼없음': 1601,
#  '조낸재미없다': 1602,
#  '개인적으로': 385,
#  '크리스': 1603,
#  '종이컵': 1604,
#  '너무': 2,
#  '평높게': 1605,
#  '서': 2882,
#  '말인가': 1607,
#  '학생의': 1608,
#  '모르겠는': 1609,
#  '개지루하다...너무': 2225,
#  '기대를': 1612,
#  '보면?': 1613,
#  '유혹하는데': 1614,
#  '진주가': 1616,
#  '미안하다~~': 1617,
#  '이해했음..': 1618,
#  '트루먼숀가..?!!!': 1619,
#  '폭력과': 1621,
#  '장난슈': 1622,
#  '전작들에서': 1623,
#  '집에': 1624,
#  '향한': 209,
#  '정도...': 1626,
#  '동물': 387,
#  '웃기든가': 1627,
#  '궁금하다.': 1628,
#  '뭘': 139,
#  '모르겠다.': 1629,
#  '봣는데': 230,
#  '바람이다!': 1630,
#  '성악': 1631,
#  '색칠해': 1633,
#  ')미투': 1634,
#  '평이높은': 1635,
#  '10억들었을까': 1637,
#  '아무생각': 1638,
#  '봤다가': 1639,
#  '겨루기엔': 1280,
#  '한국영화': 449,
#  '이명박씨': 1642,
#  '아니지만': 1643,
#  '개막장': 1644,
#  '만화를': 1645,
#  '안된다': 1647,
#  '이야기인가?': 1648,
#  '무엇을': 390,
#  '집중할수가': 1651,
#  '밧어요...': 1652,
#  ...}

# %%
# 단어 -> index
word2id["영화"]
# Out:
# 4

# %%
id2word[:10]
# Out:
# ['SENTENCE_START',
#  'SENTENCE_END',
#  '너무',
#  '진짜',
#  '영화',
#  '정말',
#  '평점이',
#  '그냥',
#  '영화.',
#  '다']

# %%
id2word[-10:]
# Out:
# ['영화는...이라는',
#  '새것이었던',
#  '관람후',
#  '비추!!!',
#  '연기자는',
#  '최악임',
#  '무엇인지...',
#  '결여되고',
#  '한물',
#  'UNKNOWN_TOKEN']

# %%
# 전체 단어 개수
len(id2word)
# Out:
# 3000

# %%
# index -> 단어
id2word[2]
# Out:
# '너무'

# %%
# 원래 이랬던 리뷰 데이터가..
text_tokenized[:30]
# Out:
# ['SENTENCE_START',
#  '극장에서',
#  '돈내고',
#  '보긴아깝다',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '진짜,,',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '훌륭하지만',
#  '비약적인',
#  '스토리',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  'OOO야..',
#  '아',
#  '진짜',
#  '후회했음',
#  '후회막급',
#  '!',
#  '!',
#  '오빠테',
#  '욕먹었음...',
#  '-_-',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '잼씀',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '지']

# %%
# 저빈도 단어 필터링 ( 토크나이징된 데이터 중 단어 사전에 등록된 것이 있으면 그대로 쓰고, 없으면 UNKNOWN_TOKEN로 대체.)
text_tokenized = [w if w in word2id else unknown_token for w in text_tokenized]
text_tokenized[:30]
# Out:
# ['SENTENCE_START',
#  '극장에서',
#  '돈내고',
#  'UNKNOWN_TOKEN',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '진짜,,',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '훌륭하지만',
#  '비약적인',
#  '스토리',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  'UNKNOWN_TOKEN',
#  '아',
#  '진짜',
#  'UNKNOWN_TOKEN',
#  'UNKNOWN_TOKEN',
#  '!',
#  '!',
#  '오빠테',
#  '욕먹었음...',
#  '-_-',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  '잼씀',
#  'SENTENCE_END',
#  'SENTENCE_START',
#  'UNKNOWN_TOKEN']

# %%
# 위의 데이터에서 각 단어를 학습을 위해 id로 치환.
tensor = np.array(list(map(word2id.get, text_tokenized)))

# %%
tensor[:100]
# Out:
# array([   0,   84,  429, 2999,    1,    0, 2230,    1,    0, 1580, 2012,
#          43,    1,    0, 2999,   48,    3, 2999, 2999,  425,  425, 2734,
#        1209,  102,    1,    0, 2918,    1,    0, 2999, 2999, 1938, 2999,
#         689, 1385, 1017,  711, 1387, 2596, 2999,    9, 1978, 2668, 2641,
#        2999, 2999,  796, 2030, 1276, 2683,  356, 2999, 1185,    1,    0,
#        2999,    1,    0,    3, 2746,  234,    1,    0,  184,    1,    0,
#        2487,  487, 2999,   27, 2999, 1444,  648,  511,    1,    0, 2740,
#           1,    0,   65, 1102,  133,    1,    0, 2999,    1,    0, 2828,
#         370,   10,   26, 2999,  197,  367,  216,  181,    4,    1,    0,
#          19])

# %% [markdown]
# ## 3. Build Batches for Training

# %%
batch_size = 20 # 배치사이즈
seq_length = 10 # rnn 모델에서 t의 사이즈

# %%
def create_batches(tensor, batch_size, seq_length):
    num_batches = int(tensor.size / (batch_size * seq_length))
    if num_batches == 0:
        assert False, "Not enough data. Make seq_length and batch_size small."

    tensor = tensor[:num_batches * batch_size * seq_length]
    xdata = tensor
    ydata = np.copy(tensor)

    ydata[:-1] = xdata[1:]
    ydata[-1] = xdata[0]
    x_batches = np.split(xdata.reshape(batch_size, -1), num_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), num_batches, 1)

    return x_batches, y_batches

# %%
x_batches, y_batches = create_batches(tensor, batch_size, seq_length)
num_batches = len(x_batches)

# %%
num_batches
# Out:
# 43

# %% [markdown]
# ### 전처리 결과

# %%
# 원 문장
text_tokenized[:5]
# Out:
# ['SENTENCE_START', '극장에서', '돈내고', '보긴아깝다', 'SENTENCE_END']

# %%
# 원 문장 각 단어를 인덱스로 표현
[word2id[w] for w in text_tokenized[:5]]
# Out:
# [1, 94, 559, 2437, 0]

# %%
# 학습에 사용되는 X_train 데이터
x_batches[1]
# Out:
# array([[2999,   40,    0,    1, 2009,   53,    3, 2999, 1857,  529],
#        [   0,    1, 2999,  191, 2999, 2999, 1885,    0,    1,  734],
#        [   1, 1925, 1187,  145, 1585,    0,    1,  213, 2999, 2999],
#        [ 158, 2425,    0,    1,  559, 2518, 2999,   43,    0,    1],
#        [ 150, 1682,    0,    1, 2999,    5, 2999,  325, 2999, 2999],
#        [   0,    1, 2785,  114, 1366,    0,    1,    2, 2364,   24],
#        [ 551,  622,   77, 1285,  967, 2999,    0,    1,  226,    0],
#        [   1, 1939,  706, 1798,    4, 2999, 2999, 2999,    2, 1483],
#        [2999, 2999, 1458,    0,    1, 2999, 1686, 2764, 2642,   60],
#        [   0,    1, 1491,    0,    1,   41, 2999,  505, 2603,   70],
#        [1859,    0,    1,  412, 2999,  514,    6, 2999,    0,    1],
#        [ 523,    9,  186,   14, 2616,  799,    0,    1, 2261, 2999],
#        [2245,    4,  259,    0,    1,  129, 2999, 1412, 2999,    0],
#        [2800,    0,    1,   52, 2999,  642, 2999, 1314, 2719,    0],
#        [2862,  589, 2171, 2999,    0,    1,  124, 2250,    0,    1],
#        [   0,    1,   32, 1260,    2, 2170, 2999,  642,    0,    1],
#        [   0,    1,  465,  741, 2680,  330, 2999,    4,    0,    1],
#        [2999,    0,    1, 2999,   29, 2999,   38, 2999,    0,    1],
#        [   1, 2999,  478, 2601, 2856,   42, 1938, 2999, 2715,    0],
#        [   1, 1540,   20, 2999, 2296,  297,   55,  297,    0,    1]])

# %%
# 학습에 사용되는 y_train 데이터
y_batches[1]
# Out:
# array([[  40,    0,    1, 2009,   53,    3, 2999, 1857,  529,  529],
#        [   1, 2999,  191, 2999, 2999, 1885,    0,    1,  734,   27],
#        [1925, 1187,  145, 1585,    0,    1,  213, 2999, 2999,    0],
#        [2425,    0,    1,  559, 2518, 2999,   43,    0,    1, 1259],
#        [1682,    0,    1, 2999,    5, 2999,  325, 2999, 2999, 2999],
#        [   1, 2785,  114, 1366,    0,    1,    2, 2364,   24,  230],
#        [ 622,   77, 1285,  967, 2999,    0,    1,  226,    0,    1],
#        [1939,  706, 1798,    4, 2999, 2999, 2999,    2, 1483, 2999],
#        [2999, 1458,    0,    1, 2999, 1686, 2764, 2642,   60, 2999],
#        [   1, 1491,    0,    1,   41, 2999,  505, 2603,   70, 1460],
#        [   0,    1,  412, 2999,  514,    6, 2999,    0,    1,  503],
#        [   9,  186,   14, 2616,  799,    0,    1, 2261, 2999,    0],
#        [   4,  259,    0,    1,  129, 2999, 1412, 2999,    0,    1],
#        [   0,    1,   52, 2999,  642, 2999, 1314, 2719,    0,    1],
#        [ 589, 2171, 2999,    0,    1,  124, 2250,    0,    1, 2999],
#        [   1,   32, 1260,    2, 2170, 2999,  642,    0,    1,    3],
#        [   1,  465,  741, 2680,  330, 2999,    4,    0,    1, 2999],
#        [   0,    1, 2999,   29, 2999,   38, 2999,    0,    1, 2999],
#        [2999,  478, 2601, 2856,   42, 1938, 2999, 2715,    0,    1],
#        [1540,   20, 2999, 2296,  297,   55,  297,    0,    1, 2482]])

# %% [markdown]
# <br><br><br><br>
# # Step 2. RNN Modeling
# <hr style="border-color:#ff9900">
# ![](img/RNN_model.png)

# %% [markdown]
# ## 1. Initialization
# - 파라미터 U,V,W 를 초기화.

# %%
args = {}
args['data_dir'] = './data'
args['log_dir'] = './logs'
args['save_dir'] = './save'
args['rnn_size'] = 256
args['num_layers'] = 5
args['model'] = 'lstm'
args['batch_size'] = batch_size
args['seq_length'] = seq_length
args['num_epochs'] = 10
args['save_every'] = 1000
args['grad_clip'] = 5
args['learning_rate'] = 0.002 
args['decay_rate'] = 0.97 
args['vocab_size'] = vocab_size

# %% [markdown]
# <img src="https://qph.ec.quoracdn.net/main-qimg-1ec77cdbb354c3b9d439fbe436dc5d4f" />

# %%
with open(os.path.join(args['save_dir'], 'config.pkl'), 'wb') as f:
    pickle.dump(args, f)
with open(os.path.join(args['save_dir'], 'words_vocab.pkl'), 'wb') as f:
    pickle.dump((id2word, word2id), f)

# %%
class Model():
    def __init__(self, args, infer=False):
        self.args = args
        if infer:
            args['batch_size'] = 1
            args['seq_length'] = 1

        if args['model'] == 'rnn':
            cell_fn = rnn_cell.BasicRNNCell
        elif args['model'] == 'gru':
            cell_fn = rnn_cell.GRUCell
        elif args['model'] == 'lstm':
            cell_fn = rnn_cell.LSTMCell
        else:
            raise Exception("model type not supported: {}".format(args['model']))

        cell = cell_fn(args['rnn_size'])

        self.cell = cell = rnn_cell.MultiRNNCell([cell] * args['num_layers'])
        self.input_data = tf.placeholder(tf.int32, [args['batch_size'], args['seq_length']])
        self.targets = tf.placeholder(tf.int32, [args['batch_size'], args['seq_length']])
        self.initial_state = cell.zero_state(args['batch_size'], tf.float32)
        self.epoch_pointer = tf.Variable(0, name="epoch_pointer", trainable=False)
        self.batch_time = tf.Variable(0.0, name="batch_time", trainable=False)

        softmax_w = tf.get_variable("softmax_w", [args['rnn_size'], args['vocab_size']])
        softmax_b = tf.get_variable("softmax_b", [args['vocab_size']])
        with tf.device("/cpu:0"):
            embedding = tf.get_variable("embedding", [args['vocab_size'], args['rnn_size']])
            inputs = tf.split(1, args['seq_length'], tf.nn.embedding_lookup(embedding, self.input_data))
            inputs = [tf.squeeze(input_, [1]) for input_ in inputs]

        def loop(prev, _):
            prev = tf.matmul(prev, softmax_w) + softmax_b
            prev_symbol = tf.stop_gradient(tf.argmax(prev, 1))
            return tf.nn.embedding_lookup(embedding, prev_symbol)

        outputs, last_state = seq2seq.rnn_decoder(inputs, self.initial_state, cell, loop_function=loop if infer else None, scope='rnnlm')
        output = tf.reshape(tf.concat(1, outputs), [-1, args['rnn_size']])
        self.logits = tf.matmul(output, softmax_w) + softmax_b
        self.probs = tf.nn.softmax(self.logits)
        loss = seq2seq.sequence_loss_by_example([self.logits],
                                                [tf.reshape(self.targets, [-1])],
                                                [tf.ones([args['batch_size'] * args['seq_length']])],
                                                args['vocab_size'])
        self.cost = tf.reduce_sum(loss) / args['batch_size'] / args['seq_length']
        self.final_state = last_state
        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars), args['grad_clip'])
        optimizer = tf.train.AdamOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def sample(self, sess, id2word, word2id, prime='SENTENCE_START'):
        state = sess.run(self.cell.zero_state(1, tf.float32))

        if not len(prime) or prime == " ":
            prime = random.choice(list(word2id.keys()))

        def weighted_pick(weights):
            t = np.cumsum(weights)
            s = np.sum(weights)
            return (int(np.searchsorted(t, np.random.rand(1) * s)))
        sent = [prime]
        word = prime.split()[-1]
        n = 0
        while sent[-1] != 'SENTENCE_END':
            x = np.zeros((1, 1))
            x[0, 0] = word2id[word]
            feed = {self.input_data: x, self.initial_state: state}
            probs, state = sess.run([self.probs, self.final_state], feed)
            p = probs[0]
            sample = weighted_pick(p)
            pred = id2word[sample]
            if pred == "UNKNOWN_TOKEN":
                continue
            sent.append(pred)
            word = pred
        return sent[1:-1]

# %%
model = Model(args)

# %%
with tf.Session() as sess:
    tf.global_variables_initializer().run() # tf 변수들 초기화
    saver = tf.train.Saver(tf.global_variables())

    for e in range(model.epoch_pointer.eval(), args['num_epochs']):
        print('\n\n--------- epoch : %i -----------\n\n' % e)
        sess.run(tf.assign(model.lr, args['learning_rate'] * (args['decay_rate'] ** e)))  # model.lr에 값 할당.
        state = sess.run(model.initial_state)
        speed = 0

        for b, (x_batch, y_batch) in enumerate(zip(x_batches, y_batches)):
            start = time.time()

            feed = {model.input_data: x_batch,
                    model.targets: y_batch,
                    model.initial_state: state,
                    model.batch_time: speed
                    }
            train_loss, state, _ = sess.run([model.cost, model.final_state, model.train_op], feed)
            speed = time.time() - start
            if (e * num_batches + b) % args['batch_size'] == 0:
                print("{}/{} (epoch {}), train_loss = {:.3f}, time/batch = {:.3f}".format(e * num_batches + b, args['num_epochs'] * num_batches, e, train_loss, speed))
            if (e * num_batches + b) % args['save_every'] == 0 or (e == args['num_epochs'] - 1 and b == num_batches - 1):  # save for the last result
                checkpoint_path = os.path.join(args['save_dir'], 'model.ckpt')
                saver.save(sess, checkpoint_path, global_step=e * num_batches + b)
                print("model saved to {}".format(checkpoint_path))
# Out:
# --------- epoch : 0 -----------
#
#
# 0/430 (epoch 0), train_loss = 8.498, time/batch = 0.313
# model saved to ./save/model.ckpt
# 20/430 (epoch 0), train_loss = 6.129, time/batch = 0.116
# 40/430 (epoch 0), train_loss = 6.346, time/batch = 0.109
#
#
# --------- epoch : 1 -----------
#
#
# 60/430 (epoch 1), train_loss = 5.655, time/batch = 0.103
# 80/430 (epoch 1), train_loss = 6.462, time/batch = 0.106
#
#
# --------- epoch : 2 -----------
#
#
# 100/430 (epoch 2), train_loss = 5.329, time/batch = 0.116
# 120/430 (epoch 2), train_loss = 5.828, time/batch = 0.114
#
#
# --------- epoch : 3 -----------
#
#
# 140/430 (epoch 3), train_loss = 5.677, time/batch = 0.109
# 160/430 (epoch 3), train_loss = 5.567, time/batch = 0.112
#
#
# --------- epoch : 4 -----------
#
#
# 180/430 (epoch 4), train_loss = 5.703, time/batch = 0.121
# 200/430 (epoch 4), train_loss = 5.848, time/batch = 0.116
#
#
# --------- epoch : 5 -----------
#
#
# 220/430 (epoch 5), train_loss = 5.360, time/batch = 0.120
# 240/430 (epoch 5), train_loss = 5.633, time/batch = 0.116
#
#
# --------- epoch : 6 -----------
#
#
# 260/430 (epoch 6), train_loss = 5.454, time/batch = 0.136
# 280/430 (epoch 6), train_loss = 5.587, time/batch = 0.148
# 300/430 (epoch 6), train_loss = 5.859, time/batch = 0.118
#
#
# --------- epoch : 7 -----------
#
#
# 320/430 (epoch 7), train_loss = 5.250, time/batch = 0.153
# 340/430 (epoch 7), train_loss = 5.364, time/batch = 0.124
#
#
# --------- epoch : 8 -----------
#
#
# 360/430 (epoch 8), train_loss = 5.216, time/batch = 0.116
# 380/430 (epoch 8), train_loss = 5.193, time/batch = 0.120
#
#
# --------- epoch : 9 -----------
#
#
# 400/430 (epoch 9), train_loss = 5.599, time/batch = 0.117
# 420/430 (epoch 9), train_loss = 5.271, time/batch = 0.119
# model saved to ./save/model.ckpt

# %% [markdown]
# <br><br><br><br>
# # Step 3. Generating Text
# <hr style="border-color:#ff9900">

# %% [markdown]
# ### 저장된 모델 불러오기

# %%
args={}
args['save_dir'] = './save'
args['prime'] = 'SENTENCE_START'

# %%
with open(os.path.join(args['save_dir'], 'config.pkl'), 'rb') as f:
    saved_args = pickle.load(f)
with open(os.path.join(args['save_dir'], 'words_vocab.pkl'), 'rb') as f:
    id2word, word2id = pickle.load(f)

# %%
tf.reset_default_graph() # 그래프 리셋
model_gen = Model(saved_args, infer=True)

# %% [markdown]
# ### 악평 생성하기

# %%
# 생성할 문장 수
num_sentences = 10
# 문장의 최소 길이
senten_min_length = 4

# %%
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    saver = tf.train.Saver(tf.global_variables())
    ckpt = tf.train.get_checkpoint_state(args['save_dir'])
    print(ckpt.model_checkpoint_path)
    if ckpt and ckpt.model_checkpoint_path:
        saver.restore(sess, ckpt.model_checkpoint_path)
        for _ in range(num_sentences):
            bot_sent = []
            while len(bot_sent) < senten_min_length:
                bot_sent = model_gen.sample(sess, id2word, word2id, args['prime'])
            print(' '.join(bot_sent))
            print()
# Out:
# ./save/model.ckpt-429
# 머하는거지? 중간까지 손발 어설프다...지루하다.. 찬사를 너무 최저. 없음. 의리 가정에 죽겠다. 오와 없는 실화라는 할수 충분히 최악의 아쉽다 감동 재미없는
#
# 시리즈중 관계자들이 3류보다 서부극 의리!있는 작가가 SENTENCE_START 피해망상 SENTENCE_START SENTENCE_START 맞는건지는 괜찮았는데..이번작은 쓰기에 SENTENCE_START 허지웅을 SENTENCE_START 제대로된 영화...연출력도
#
# 발전한것 팬들 보고 SENTENCE_START 오바심함
#
# 매번 그들은 후회막급 영!! 낭비했다.
#
# 잃어버린 이해되질 없음..절대 이야기이네요...근디 감동포인트를 했다. 흠..그냥 실망 못한
#
# 역량이 일본만화는 떡 최악이라는 메릴스트립과 런닝타임만 쓰레기. SENTENCE_START 한 쌔고쌨는데ㅉㅉㅉ 한것 진짜 재밌었다... 아닌데... 또는 SENTENCE_START 진짜,, 재능 꺄악꺄악...-_- 추억의 인간의 애니를 수동적으로 너무 아까운영화 딱히 SENTENCE_START 오만은 SENTENCE_START SENTENCE_START 영화는 너무
#
# ffff 몰락의 딱 박수칠때 지루하고 요새 SENTENCE_START 평론가들에게
#
# 학대해도 머하는거지? 미쳐서 시간아깝다. 울
#
# 실제로 2점부터 싫고쓰레기고엉터리고 안돼 ㅡㅡ 진짜 SENTENCE_START SENTENCE_START 이영화에 영화가
#
# 일탈도 아니라 7점 싫다 를 전작을 안됨 SENTENCE_START 보기도 SENTENCE_START SENTENCE_START 많았던것 못하네요.. 일본 듣기 쓰레기다. ㅋㅋ 잠들었다 뻔하고 체 SENTENCE_START 영화...연출력도 만들어도 8점대래? SENTENCE_START 영화관에 열심히 권력을 아.. 다 초,중,고딩용 SENTENCE_START 좋은 SENTENCE_START 이런 죽여야만
#
# 중간에 안됨 토나온다고 해달라.누가 별내용도 오지게 , 정신나간 하기는... 학생인 공헌했음.
#
# 보니까 감정선이 아쉽다 나와서 이런거지. 사느냐에 조연들... 애니메이션으로 15세
#
# 한사람들은 약속이다. 애니메이션!! 영화가되길 봤네; 에피소드의 애니메이션과 젊은남자를 SENTENCE_START 더빙도 기대에 분노가
#
# 초반에 별로다. 따른 생각이니 죽음의 평가했을때 하품하고 돈내고 아직 SENTENCE_START 없는데 진짜 SENTENCE_START 참석이라니 있었는데..마지막은 감독이 영화라는 두고
#
# 안돼 시리즈중 주변 공감전혀안됨 두시간 SENTENCE_START 다 아 그냥 후회막급 항상 저 점수도

# %% [markdown]
# <br><br><br><br>
# # Evaluation & Challenging
# <hr style="border-color:#ff9900">
